# %% [markdown]
# # 01: Prepare brightway
#
# In this script, we create a new brightway project, import ecoinvent and add all necessary LCIA methods.

# %%
# %run common_definitions.py

# %%
import bw2data as bd
import bw2io as bi
from premise_gwp import add_premise_gwp

import pandas as pd
import os

# %% [markdown]
# ## Create a new brightway project

# %%
premise_version = "2.3.0.dev1"
ei_label = "ecoinvent-{}-cutoff".format(EI_VERSION)
project_name = "premise_runs_{}_{}".format(EI_VERSION, premise_version)

# %% [markdown]
# ## Import ecoinvent

# %%
# import ecoinvent databases
bd.projects.set_current(project_name)
bi.import_ecoinvent_release(
    version=EI_VERSION,
    system_model="cutoff",
    username="pik",
    password="8FragAvBar!"
)
# Out:
# Writing activities to SQLite3 database:
# Applying strategy: normalize_units
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: ensure_categories_are_tuples
# Applied 3 strategies in 0.01 seconds
# 4718 datasets
# 0 exchanges
# 0 unlinked exchanges
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# Title: Writing activities to SQLite3 database:
#   Started: 07/30/2025 11:28:42
#   Finished: 07/30/2025 11:28:42
#   Total time elapsed: 00:00:00
#   CPU %: 86.80
#   Memory %: 1.57
# Created database: ecoinvent-3.9.1-biosphere
# Extracting ecospold2 files:
# 0% [##############################] 100% | ETA: 00:00:00 | Item ID: fffede58-fed2-5
# Total time elapsed: 00:02:49
# Title: Extracting ecospold2 files:
#   Started: 07/30/2025 11:28:54
#   Finished: 07/30/2025 11:31:44
#   Total time elapsed: 00:02:49
#   CPU %: 82.60
#   Memory %: 18.25
# Extracted 21238 datasets in 172.34 seconds
# Applying strategy: normalize_units
# Applying strategy: update_ecoinvent_locations
# Applying strategy: remove_zero_amount_coproducts
# Applying strategy: remove_zero_amount_inputs_with_no_activity
# Applying strategy: remove_unnamed_parameters
# Applying strategy: es2_assign_only_product_with_amount_as_reference_product
# Applying strategy: assign_single_product_as_activity
# Applying strategy: create_composite_code
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: fix_ecoinvent_flows_pre35
# Applying strategy: drop_temporary_outdated_biosphere_flows
# Applying strategy: link_biosphere_by_flow_uuid
# Applying strategy: link_internal_technosphere_by_composite_code
# Applying strategy: delete_exchanges_missing_activity
# Applying strategy: delete_ghost_exchanges
# Applying strategy: remove_uncertainty_from_negative_loss_exchanges
# Applying strategy: fix_unreasonably_high_lognormal_uncertainties
# Applying strategy: convert_activity_parameters_to_list
# Applying strategy: add_cpc_classification_from_single_reference_product
# Applying strategy: delete_none_synonyms
# Applying strategy: update_social_flows_in_older_consequential
# Applying strategy: set_lognormal_loc_value
# Applied 22 strategies in 6.20 seconds
# Writing activities to SQLite3 database:
# 21238 datasets
# 674593 exchanges
# 0 unlinked exchanges
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:31
# Title: Writing activities to SQLite3 database:
#   Started: 07/30/2025 11:31:50
#   Finished: 07/30/2025 11:32:22
#   Total time elapsed: 00:00:31
#   CPU %: 95.60
#   Memory %: 19.03
# Created database: ecoinvent-3.9.1-cutoff

# %% [markdown]
# ## Adding premise_gwp methods
#
# This function adds climate change LCIA methods with biogenic flows.

# %%
add_premise_gwp()
# Out:
# RELICS requires the name of your biosphere database.
# Please enter the name of your biosphere database as it appears in your project.
# Databases dictionary with 2 object(s):
# 	ecoinvent-3.9.1-biosphere
# 	ecoinvent-3.9.1-cutoff
# Adding ('IPCC 2021', 'climate change', 'GWP 20a, incl. H and bio CO2')
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: set_biosphere_type
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: link_iterable_by_fields
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applied 8 strategies in 0.10 seconds
# Wrote 1 LCIA methods with 255 characterization factors
# Adding ('IPCC 2021', 'climate change', 'GWP 20a, incl. H')
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: set_biosphere_type
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: link_iterable_by_fields
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applied 8 strategies in 0.10 seconds
# Wrote 1 LCIA methods with 248 characterization factors
# Adding ('IPCC 2021', 'climate change', 'GWP 100a, incl. H')
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: set_biosphere_type
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: link_iterable_by_fields
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applied 8 strategies in 0.10 seconds
# Wrote 1 LCIA methods with 248 characterization factors
# Adding ('IPCC 2021', 'climate change', 'GWP 100a, incl. H and bio CO2')
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: set_biosphere_type
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: link_iterable_by_fields
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applied 8 strategies in 0.10 seconds
# Wrote 1 LCIA methods with 255 characterization factors

# %% [markdown]
# ## Create split climate change LCIA methods
#
# Now the newly created climate change LCIA methods are split into the sources `biogenic`, `land use`, and `fossil`.

# %%
base_methods = [
    ('IPCC 2021', 'climate change', 'GWP 100a, incl. H and bio CO2'),
    ('IPCC 2021', 'climate change', 'GWP 20a, incl. H and bio CO2')
]

# %%
for method in base_methods:
    M = bd.Method(method)
    unit = ""
    if "unit" in M.metadata:
        unit = M.metadata["unit"]

    CFs_bio = []
    CFs_landuse = []
    CFs_fossil = []
    for flow in bd.Method(method).load():
        act = bd.get_activity(flow[0])
        if "non-fossil" in act["name"] or "in air" in act["name"]:
            CFs_bio.append(list(flow))
        elif "soil or biomass" in act["name"]:
            CFs_landuse.append(list(flow))
        else:
            CFs_fossil.append(list(flow))

    new_key = (method[0], method[1]+": biogenic", method[2].split(",")[0])    
    new_method = bd.Method(new_key)
    new_method.validate(CFs_bio)
    new_method.register(unit=unit)
    new_method.write(CFs_bio)

    new_key = (method[0], method[1]+": land use", method[2].split(",")[0])    
    new_method = bd.Method(new_key)
    new_method.validate(CFs_landuse)
    new_method.register(unit=unit)
    new_method.write(CFs_landuse)

    new_key = (method[0], method[1]+": fossil", method[2].split(",")[0])    
    new_method = bd.Method(new_key)
    new_method.validate(CFs_fossil)
    new_method.register(unit=unit)
    new_method.write(CFs_fossil)

# %% [markdown]
# ## Add the Ecocosts Materials method

# %%
table = pd.read_csv("../data/cfs_ecocosts_metals.csv")
table.dropna(subset="characterization factor", inplace=True)

# %%
db = bd.Database("ecoinvent-3.9.1-biosphere")
resources = [flow for flow in db if flow["categories"] == ("natural resource", "in ground")]

new_key = ("Eco-costs", "Material scarcity", "VAR(95)")
CFs = []
for idx, row in table.iterrows():
    matches = [flow for flow in resources if flow["name"] == row["name"] and str(flow["categories"]) == row["categories"]]
    if len(matches) == 1:
        CFs.append([matches[0].key, row["characterization factor"]])
    else:
        print("Error: More than one match.")

new_method = bd.Method(new_key)
new_method.validate(CFs)
new_method.register(unit="EUR2023")
new_method.write(CFs)

# %% [markdown]
# ## Add the old ReCiPe methods
#
# Load CFs.

# %%
df_recipe = pd.read_csv("../data/cfs_old_recipe_methods_mapped.csv")

# %% [markdown]
# Find matching biosphere flows

# %%
db = bd.Database("ecoinvent-3.9.1-biosphere")

flowlist = []
categorieslist = []
keylist = []

needed_flows = list(df_recipe.groupby(["new flow name", "flow categories"]).size().index)

for j, f in enumerate(needed_flows):
    matching_names = [act for act in db if act["name"] == f[0]]
    matching_cats = [act for act in matching_names if str(act["categories"]) == f[1]]
    if len(matching_cats) == 1:
        flowlist.append(f[0])
        categorieslist.append(f[1])
        keylist.append(matching_cats[0].key)
    print("{} of {} flows checked.".format(j+1, len(needed_flows)))

flow_mapping = pd.DataFrame(
    {
        "new flow name": flowlist,
        "flow categories": categorieslist,
        "mapped key": keylist
    }
)
# Out:
# 1 of 2477 flows checked.
# 2 of 2477 flows checked.
# 3 of 2477 flows checked.
# 4 of 2477 flows checked.
# 5 of 2477 flows checked.
# 6 of 2477 flows checked.
# 7 of 2477 flows checked.
# 8 of 2477 flows checked.
# 9 of 2477 flows checked.
# 10 of 2477 flows checked.
# 11 of 2477 flows checked.
# 12 of 2477 flows checked.
# 13 of 2477 flows checked.
# 14 of 2477 flows checked.
# 15 of 2477 flows checked.
# 16 of 2477 flows checked.
# 17 of 2477 flows checked.
# 18 of 2477 flows checked.
# 19 of 2477 flows checked.
# 20 of 2477 flows checked.
# 21 of 2477 flows checked.
# 22 of 2477 flows checked.
# 23 of 2477 flows checked.
# 24 of 2477 flows checked.
# 25 of 2477 flows checked.
# 26 of 2477 flows checked.
# 27 of 2477 flows checked.
# 28 of 2477 flows checked.
# 29 of 2477 flows checked.
# 30 of 2477 flows checked.
# 31 of 2477 flows checked.
# 32 of 2477 flows checked.
# 33 of 2477 flows checked.
# 34 of 2477 flows checked.
# 35 of 2477 flows checked.
# 36 of 2477 flows checked.
# 37 of 2477 flows checked.
# 38 of 2477 flows checked.
# 39 of 2477 flows checked.
# 40 of 2477 flows checked.
# 41 of 2477 flows checked.
# 42 of 2477 flows checked.
# 43 of 2477 flows checked.
# 44 of 2477 flows checked.
# 45 of 2477 flows checked.
# 46 of 2477 flows checked.
# 47 of 2477 flows checked.
# 48 of 2477 flows checked.
# 49 of 2477 flows checked.
# 50 of 2477 flows checked.
# 51 of 2477 flows checked.
# 52 of 2477 flows checked.
# 53 of 2477 flows checked.
# 54 of 2477 flows checked.
# 55 of 2477 flows checked.
# 56 of 2477 flows checked.
# 57 of 2477 flows checked.
# 58 of 2477 flows checked.
# 59 of 2477 flows checked.
# 60 of 2477 flows checked.
# 61 of 2477 flows checked.
# 62 of 2477 flows checked.
# 63 of 2477 flows checked.
# 64 of 2477 flows checked.
# 65 of 2477 flows checked.
# 66 of 2477 flows checked.
# 67 of 2477 flows checked.
# 68 of 2477 flows checked.
# 69 of 2477 flows checked.
# 70 of 2477 flows checked.
# 71 of 2477 flows checked.
# 72 of 2477 flows checked.
# 73 of 2477 flows checked.
# 74 of 2477 flows checked.
# 75 of 2477 flows checked.
# 76 of 2477 flows checked.
# 77 of 2477 flows checked.
# 78 of 2477 flows checked.
# 79 of 2477 flows checked.
# 80 of 2477 flows checked.
# 81 of 2477 flows checked.
# 82 of 2477 flows checked.
# 83 of 2477 flows checked.
# 84 of 2477 flows checked.
# 85 of 2477 flows checked.
# 86 of 2477 flows checked.
# 87 of 2477 flows checked.
# 88 of 2477 flows checked.
# 89 of 2477 flows checked.
# 90 of 2477 flows checked.
# 91 of 2477 flows checked.
# 92 of 2477 flows checked.
# 93 of 2477 flows checked.
# 94 of 2477 flows checked.
# 95 of 2477 flows checked.
# 96 of 2477 flows checked.
# 97 of 2477 flows checked.
# 98 of 2477 flows checked.
# 99 of 2477 flows checked.
# 100 of 2477 flows checked.
# 101 of 2477 flows checked.
# 102 of 2477 flows checked.
# 103 of 2477 flows checked.
# 104 of 2477 flows checked.
# 105 of 2477 flows checked.
# 106 of 2477 flows checked.
# 107 of 2477 flows checked.
# 108 of 2477 flows checked.
# 109 of 2477 flows checked.
# 110 of 2477 flows checked.
# 111 of 2477 flows checked.
# 112 of 2477 flows checked.
# 113 of 2477 flows checked.
# 114 of 2477 flows checked.
# 115 of 2477 flows checked.
# 116 of 2477 flows checked.
# 117 of 2477 flows checked.
# 118 of 2477 flows checked.
# 119 of 2477 flows checked.
# 120 of 2477 flows checked.
# 121 of 2477 flows checked.
# 122 of 2477 flows checked.
# 123 of 2477 flows checked.
# 124 of 2477 flows checked.
# 125 of 2477 flows checked.
# 126 of 2477 flows checked.
# 127 of 2477 flows checked.
# 128 of 2477 flows checked.
# 129 of 2477 flows checked.
# 130 of 2477 flows checked.
# 131 of 2477 flows checked.
# 132 of 2477 flows checked.
# 133 of 2477 flows checked.
# 134 of 2477 flows checked.
# 135 of 2477 flows checked.
# 136 of 2477 flows checked.
# 137 of 2477 flows checked.
# 138 of 2477 flows checked.
# 139 of 2477 flows checked.
# 140 of 2477 flows checked.
# 141 of 2477 flows checked.
# 142 of 2477 flows checked.
# 143 of 2477 flows checked.
# 144 of 2477 flows checked.
# 145 of 2477 flows checked.
# 146 of 2477 flows checked.
# 147 of 2477 flows checked.
# 148 of 2477 flows checked.
# 149 of 2477 flows checked.
# 150 of 2477 flows checked.
# 151 of 2477 flows checked.
# 152 of 2477 flows checked.
# 153 of 2477 flows checked.
# 154 of 2477 flows checked.
# 155 of 2477 flows checked.
# 156 of 2477 flows checked.
# 157 of 2477 flows checked.
# 158 of 2477 flows checked.
# 159 of 2477 flows checked.
# 160 of 2477 flows checked.
# 161 of 2477 flows checked.
# 162 of 2477 flows checked.
# 163 of 2477 flows checked.
# 164 of 2477 flows checked.
# 165 of 2477 flows checked.
# 166 of 2477 flows checked.
# 167 of 2477 flows checked.
# 168 of 2477 flows checked.
# 169 of 2477 flows checked.
# 170 of 2477 flows checked.
# 171 of 2477 flows checked.
# 172 of 2477 flows checked.
# 173 of 2477 flows checked.
# 174 of 2477 flows checked.
# 175 of 2477 flows checked.
# 176 of 2477 flows checked.
# 177 of 2477 flows checked.
# 178 of 2477 flows checked.
# 179 of 2477 flows checked.
# 180 of 2477 flows checked.
# 181 of 2477 flows checked.
# 182 of 2477 flows checked.
# 183 of 2477 flows checked.
# 184 of 2477 flows checked.
# 185 of 2477 flows checked.
# 186 of 2477 flows checked.
# 187 of 2477 flows checked.
# 188 of 2477 flows checked.
# 189 of 2477 flows checked.
# 190 of 2477 flows checked.
# 191 of 2477 flows checked.
# 192 of 2477 flows checked.
# 193 of 2477 flows checked.
# 194 of 2477 flows checked.
# 195 of 2477 flows checked.
# 196 of 2477 flows checked.
# 197 of 2477 flows checked.
# 198 of 2477 flows checked.
# 199 of 2477 flows checked.
# 200 of 2477 flows checked.
# 201 of 2477 flows checked.
# 202 of 2477 flows checked.
# 203 of 2477 flows checked.
# 204 of 2477 flows checked.
# 205 of 2477 flows checked.
# 206 of 2477 flows checked.
# 207 of 2477 flows checked.
# 208 of 2477 flows checked.
# 209 of 2477 flows checked.
# 210 of 2477 flows checked.
# 211 of 2477 flows checked.
# 212 of 2477 flows checked.
# 213 of 2477 flows checked.
# 214 of 2477 flows checked.
# 215 of 2477 flows checked.
# 216 of 2477 flows checked.
# 217 of 2477 flows checked.
# 218 of 2477 flows checked.
# 219 of 2477 flows checked.
# 220 of 2477 flows checked.
# 221 of 2477 flows checked.
# 222 of 2477 flows checked.
# 223 of 2477 flows checked.
# 224 of 2477 flows checked.
# 225 of 2477 flows checked.
# 226 of 2477 flows checked.
# 227 of 2477 flows checked.
# 228 of 2477 flows checked.
# 229 of 2477 flows checked.
# 230 of 2477 flows checked.
# 231 of 2477 flows checked.
# 232 of 2477 flows checked.
# 233 of 2477 flows checked.
# 234 of 2477 flows checked.
# 235 of 2477 flows checked.
# 236 of 2477 flows checked.
# 237 of 2477 flows checked.
# 238 of 2477 flows checked.
# 239 of 2477 flows checked.
# 240 of 2477 flows checked.
# 241 of 2477 flows checked.
# 242 of 2477 flows checked.
# 243 of 2477 flows checked.
# 244 of 2477 flows checked.
# 245 of 2477 flows checked.
# 246 of 2477 flows checked.
# 247 of 2477 flows checked.
# 248 of 2477 flows checked.
# 249 of 2477 flows checked.
# 250 of 2477 flows checked.
# 251 of 2477 flows checked.
# 252 of 2477 flows checked.
# 253 of 2477 flows checked.
# 254 of 2477 flows checked.
# 255 of 2477 flows checked.
# 256 of 2477 flows checked.
# 257 of 2477 flows checked.
# 258 of 2477 flows checked.
# 259 of 2477 flows checked.
# 260 of 2477 flows checked.
# 261 of 2477 flows checked.
# 262 of 2477 flows checked.
# 263 of 2477 flows checked.
# 264 of 2477 flows checked.
# 265 of 2477 flows checked.
# 266 of 2477 flows checked.
# 267 of 2477 flows checked.
# 268 of 2477 flows checked.
# 269 of 2477 flows checked.
# 270 of 2477 flows checked.
# 271 of 2477 flows checked.
# 272 of 2477 flows checked.
# 273 of 2477 flows checked.
# 274 of 2477 flows checked.
# 275 of 2477 flows checked.
# 276 of 2477 flows checked.
# 277 of 2477 flows checked.
# 278 of 2477 flows checked.
# 279 of 2477 flows checked.
# 280 of 2477 flows checked.
# 281 of 2477 flows checked.
# 282 of 2477 flows checked.
# 283 of 2477 flows checked.
# 284 of 2477 flows checked.
# 285 of 2477 flows checked.
# 286 of 2477 flows checked.
# 287 of 2477 flows checked.
# 288 of 2477 flows checked.
# 289 of 2477 flows checked.
# 290 of 2477 flows checked.
# 291 of 2477 flows checked.
# 292 of 2477 flows checked.
# 293 of 2477 flows checked.
# 294 of 2477 flows checked.
# 295 of 2477 flows checked.
# 296 of 2477 flows checked.
# 297 of 2477 flows checked.
# 298 of 2477 flows checked.
# 299 of 2477 flows checked.
# 300 of 2477 flows checked.
# 301 of 2477 flows checked.
# 302 of 2477 flows checked.
# 303 of 2477 flows checked.
# 304 of 2477 flows checked.
# 305 of 2477 flows checked.
# 306 of 2477 flows checked.
# 307 of 2477 flows checked.
# 308 of 2477 flows checked.
# 309 of 2477 flows checked.
# 310 of 2477 flows checked.
# 311 of 2477 flows checked.
# 312 of 2477 flows checked.
# 313 of 2477 flows checked.
# 314 of 2477 flows checked.
# 315 of 2477 flows checked.
# 316 of 2477 flows checked.
# 317 of 2477 flows checked.
# 318 of 2477 flows checked.
# 319 of 2477 flows checked.
# 320 of 2477 flows checked.
# 321 of 2477 flows checked.
# 322 of 2477 flows checked.
# 323 of 2477 flows checked.
# 324 of 2477 flows checked.
# 325 of 2477 flows checked.
# 326 of 2477 flows checked.
# 327 of 2477 flows checked.
# 328 of 2477 flows checked.
# 329 of 2477 flows checked.
# 330 of 2477 flows checked.
# 331 of 2477 flows checked.
# 332 of 2477 flows checked.
# 333 of 2477 flows checked.
# 334 of 2477 flows checked.
# 335 of 2477 flows checked.
# 336 of 2477 flows checked.
# 337 of 2477 flows checked.
# 338 of 2477 flows checked.
# 339 of 2477 flows checked.
# 340 of 2477 flows checked.
# 341 of 2477 flows checked.
# 342 of 2477 flows checked.
# 343 of 2477 flows checked.
# 344 of 2477 flows checked.
# 345 of 2477 flows checked.
# 346 of 2477 flows checked.
# 347 of 2477 flows checked.
# 348 of 2477 flows checked.
# 349 of 2477 flows checked.
# 350 of 2477 flows checked.
# 351 of 2477 flows checked.
# 352 of 2477 flows checked.
# 353 of 2477 flows checked.
# 354 of 2477 flows checked.
# 355 of 2477 flows checked.
# 356 of 2477 flows checked.
# 357 of 2477 flows checked.
# 358 of 2477 flows checked.
# 359 of 2477 flows checked.
# 360 of 2477 flows checked.
# 361 of 2477 flows checked.
# 362 of 2477 flows checked.
# 363 of 2477 flows checked.
# 364 of 2477 flows checked.
# 365 of 2477 flows checked.
# 366 of 2477 flows checked.
# 367 of 2477 flows checked.
# 368 of 2477 flows checked.
# 369 of 2477 flows checked.
# 370 of 2477 flows checked.
# 371 of 2477 flows checked.
# 372 of 2477 flows checked.
# 373 of 2477 flows checked.
# 374 of 2477 flows checked.
# 375 of 2477 flows checked.
# 376 of 2477 flows checked.
# 377 of 2477 flows checked.
# 378 of 2477 flows checked.
# 379 of 2477 flows checked.
# 380 of 2477 flows checked.
# 381 of 2477 flows checked.
# 382 of 2477 flows checked.
# 383 of 2477 flows checked.
# 384 of 2477 flows checked.
# 385 of 2477 flows checked.
# 386 of 2477 flows checked.
# 387 of 2477 flows checked.
# 388 of 2477 flows checked.
# 389 of 2477 flows checked.
# 390 of 2477 flows checked.
# 391 of 2477 flows checked.
# 392 of 2477 flows checked.
# 393 of 2477 flows checked.
# 394 of 2477 flows checked.
# 395 of 2477 flows checked.
# 396 of 2477 flows checked.
# 397 of 2477 flows checked.
# 398 of 2477 flows checked.
# 399 of 2477 flows checked.
# 400 of 2477 flows checked.
# 401 of 2477 flows checked.
# 402 of 2477 flows checked.
# 403 of 2477 flows checked.
# 404 of 2477 flows checked.
# 405 of 2477 flows checked.
# 406 of 2477 flows checked.
# 407 of 2477 flows checked.
# 408 of 2477 flows checked.
# 409 of 2477 flows checked.
# 410 of 2477 flows checked.
# 411 of 2477 flows checked.
# 412 of 2477 flows checked.
# 413 of 2477 flows checked.
# 414 of 2477 flows checked.
# 415 of 2477 flows checked.
# 416 of 2477 flows checked.
# 417 of 2477 flows checked.
# 418 of 2477 flows checked.
# 419 of 2477 flows checked.
# 420 of 2477 flows checked.
# 421 of 2477 flows checked.
# 422 of 2477 flows checked.
# 423 of 2477 flows checked.
# 424 of 2477 flows checked.
# 425 of 2477 flows checked.
# 426 of 2477 flows checked.
# 427 of 2477 flows checked.
# 428 of 2477 flows checked.
# 429 of 2477 flows checked.
# 430 of 2477 flows checked.
# 431 of 2477 flows checked.
# 432 of 2477 flows checked.
# 433 of 2477 flows checked.
# 434 of 2477 flows checked.
# 435 of 2477 flows checked.
# 436 of 2477 flows checked.
# 437 of 2477 flows checked.
# 438 of 2477 flows checked.
# 439 of 2477 flows checked.
# 440 of 2477 flows checked.
# 441 of 2477 flows checked.
# 442 of 2477 flows checked.
# 443 of 2477 flows checked.
# 444 of 2477 flows checked.
# 445 of 2477 flows checked.
# 446 of 2477 flows checked.
# 447 of 2477 flows checked.
# 448 of 2477 flows checked.
# 449 of 2477 flows checked.
# 450 of 2477 flows checked.
# 451 of 2477 flows checked.
# 452 of 2477 flows checked.
# 453 of 2477 flows checked.
# 454 of 2477 flows checked.
# 455 of 2477 flows checked.
# 456 of 2477 flows checked.
# 457 of 2477 flows checked.
# 458 of 2477 flows checked.
# 459 of 2477 flows checked.
# 460 of 2477 flows checked.
# 461 of 2477 flows checked.
# 462 of 2477 flows checked.
# 463 of 2477 flows checked.
# 464 of 2477 flows checked.
# 465 of 2477 flows checked.
# 466 of 2477 flows checked.
# 467 of 2477 flows checked.
# 468 of 2477 flows checked.
# 469 of 2477 flows checked.
# 470 of 2477 flows checked.
# 471 of 2477 flows checked.
# 472 of 2477 flows checked.
# 473 of 2477 flows checked.
# 474 of 2477 flows checked.
# 475 of 2477 flows checked.
# 476 of 2477 flows checked.
# 477 of 2477 flows checked.
# 478 of 2477 flows checked.
# 479 of 2477 flows checked.
# 480 of 2477 flows checked.
# 481 of 2477 flows checked.
# 482 of 2477 flows checked.
# 483 of 2477 flows checked.
# 484 of 2477 flows checked.
# 485 of 2477 flows checked.
# 486 of 2477 flows checked.
# 487 of 2477 flows checked.
# 488 of 2477 flows checked.
# 489 of 2477 flows checked.
# 490 of 2477 flows checked.
# 491 of 2477 flows checked.
# 492 of 2477 flows checked.
# 493 of 2477 flows checked.
# 494 of 2477 flows checked.
# 495 of 2477 flows checked.
# 496 of 2477 flows checked.
# 497 of 2477 flows checked.
# 498 of 2477 flows checked.
# 499 of 2477 flows checked.
# 500 of 2477 flows checked.
# 501 of 2477 flows checked.
# 502 of 2477 flows checked.
# 503 of 2477 flows checked.
# 504 of 2477 flows checked.
# 505 of 2477 flows checked.
# 506 of 2477 flows checked.
# 507 of 2477 flows checked.
# 508 of 2477 flows checked.
# 509 of 2477 flows checked.
# 510 of 2477 flows checked.
# 511 of 2477 flows checked.
# 512 of 2477 flows checked.
# 513 of 2477 flows checked.
# 514 of 2477 flows checked.
# 515 of 2477 flows checked.
# 516 of 2477 flows checked.
# 517 of 2477 flows checked.
# 518 of 2477 flows checked.
# 519 of 2477 flows checked.
# 520 of 2477 flows checked.
# 521 of 2477 flows checked.
# 522 of 2477 flows checked.
# 523 of 2477 flows checked.
# 524 of 2477 flows checked.
# 525 of 2477 flows checked.
# 526 of 2477 flows checked.
# 527 of 2477 flows checked.
# 528 of 2477 flows checked.
# 529 of 2477 flows checked.
# 530 of 2477 flows checked.
# 531 of 2477 flows checked.
# 532 of 2477 flows checked.
# 533 of 2477 flows checked.
# 534 of 2477 flows checked.
# 535 of 2477 flows checked.
# 536 of 2477 flows checked.
# 537 of 2477 flows checked.
# 538 of 2477 flows checked.
# 539 of 2477 flows checked.
# 540 of 2477 flows checked.
# 541 of 2477 flows checked.
# 542 of 2477 flows checked.
# 543 of 2477 flows checked.
# 544 of 2477 flows checked.
# 545 of 2477 flows checked.
# 546 of 2477 flows checked.
# 547 of 2477 flows checked.
# 548 of 2477 flows checked.
# 549 of 2477 flows checked.
# 550 of 2477 flows checked.
# 551 of 2477 flows checked.
# 552 of 2477 flows checked.
# 553 of 2477 flows checked.
# 554 of 2477 flows checked.
# 555 of 2477 flows checked.
# 556 of 2477 flows checked.
# 557 of 2477 flows checked.
# 558 of 2477 flows checked.
# 559 of 2477 flows checked.
# 560 of 2477 flows checked.
# 561 of 2477 flows checked.
# 562 of 2477 flows checked.
# 563 of 2477 flows checked.
# 564 of 2477 flows checked.
# 565 of 2477 flows checked.
# 566 of 2477 flows checked.
# 567 of 2477 flows checked.
# 568 of 2477 flows checked.
# 569 of 2477 flows checked.
# 570 of 2477 flows checked.
# 571 of 2477 flows checked.
# 572 of 2477 flows checked.
# 573 of 2477 flows checked.
# 574 of 2477 flows checked.
# 575 of 2477 flows checked.
# 576 of 2477 flows checked.
# 577 of 2477 flows checked.
# 578 of 2477 flows checked.
# 579 of 2477 flows checked.
# 580 of 2477 flows checked.
# 581 of 2477 flows checked.
# 582 of 2477 flows checked.
# 583 of 2477 flows checked.
# 584 of 2477 flows checked.
# 585 of 2477 flows checked.
# 586 of 2477 flows checked.
# 587 of 2477 flows checked.
# 588 of 2477 flows checked.
# 589 of 2477 flows checked.
# 590 of 2477 flows checked.
# 591 of 2477 flows checked.
# 592 of 2477 flows checked.
# 593 of 2477 flows checked.
# 594 of 2477 flows checked.
# 595 of 2477 flows checked.
# 596 of 2477 flows checked.
# 597 of 2477 flows checked.
# 598 of 2477 flows checked.
# 599 of 2477 flows checked.
# 600 of 2477 flows checked.
# 601 of 2477 flows checked.
# 602 of 2477 flows checked.
# 603 of 2477 flows checked.
# 604 of 2477 flows checked.
# 605 of 2477 flows checked.
# 606 of 2477 flows checked.
# 607 of 2477 flows checked.
# 608 of 2477 flows checked.
# 609 of 2477 flows checked.
# 610 of 2477 flows checked.
# 611 of 2477 flows checked.
# 612 of 2477 flows checked.
# 613 of 2477 flows checked.
# 614 of 2477 flows checked.
# 615 of 2477 flows checked.
# 616 of 2477 flows checked.
# 617 of 2477 flows checked.
# 618 of 2477 flows checked.
# 619 of 2477 flows checked.
# 620 of 2477 flows checked.
# 621 of 2477 flows checked.
# 622 of 2477 flows checked.
# 623 of 2477 flows checked.
# 624 of 2477 flows checked.
# 625 of 2477 flows checked.
# 626 of 2477 flows checked.
# 627 of 2477 flows checked.
# 628 of 2477 flows checked.
# 629 of 2477 flows checked.
# 630 of 2477 flows checked.
# 631 of 2477 flows checked.
# 632 of 2477 flows checked.
# 633 of 2477 flows checked.
# 634 of 2477 flows checked.
# 635 of 2477 flows checked.
# 636 of 2477 flows checked.
# 637 of 2477 flows checked.
# 638 of 2477 flows checked.
# 639 of 2477 flows checked.
# 640 of 2477 flows checked.
# 641 of 2477 flows checked.
# 642 of 2477 flows checked.
# 643 of 2477 flows checked.
# 644 of 2477 flows checked.
# 645 of 2477 flows checked.
# 646 of 2477 flows checked.
# 647 of 2477 flows checked.
# 648 of 2477 flows checked.
# 649 of 2477 flows checked.
# 650 of 2477 flows checked.
# 651 of 2477 flows checked.
# 652 of 2477 flows checked.
# 653 of 2477 flows checked.
# 654 of 2477 flows checked.
# 655 of 2477 flows checked.
# 656 of 2477 flows checked.
# 657 of 2477 flows checked.
# 658 of 2477 flows checked.
# 659 of 2477 flows checked.
# 660 of 2477 flows checked.
# 661 of 2477 flows checked.
# 662 of 2477 flows checked.
# 663 of 2477 flows checked.
# 664 of 2477 flows checked.
# 665 of 2477 flows checked.
# 666 of 2477 flows checked.
# 667 of 2477 flows checked.
# 668 of 2477 flows checked.
# 669 of 2477 flows checked.
# 670 of 2477 flows checked.
# 671 of 2477 flows checked.
# 672 of 2477 flows checked.
# 673 of 2477 flows checked.
# 674 of 2477 flows checked.
# 675 of 2477 flows checked.
# 676 of 2477 flows checked.
# 677 of 2477 flows checked.
# 678 of 2477 flows checked.
# 679 of 2477 flows checked.
# 680 of 2477 flows checked.
# 681 of 2477 flows checked.
# 682 of 2477 flows checked.
# 683 of 2477 flows checked.
# 684 of 2477 flows checked.
# 685 of 2477 flows checked.
# 686 of 2477 flows checked.
# 687 of 2477 flows checked.
# 688 of 2477 flows checked.
# 689 of 2477 flows checked.
# 690 of 2477 flows checked.
# 691 of 2477 flows checked.
# 692 of 2477 flows checked.
# 693 of 2477 flows checked.
# 694 of 2477 flows checked.
# 695 of 2477 flows checked.
# 696 of 2477 flows checked.
# 697 of 2477 flows checked.
# 698 of 2477 flows checked.
# 699 of 2477 flows checked.
# 700 of 2477 flows checked.
# 701 of 2477 flows checked.
# 702 of 2477 flows checked.
# 703 of 2477 flows checked.
# 704 of 2477 flows checked.
# 705 of 2477 flows checked.
# 706 of 2477 flows checked.
# 707 of 2477 flows checked.
# 708 of 2477 flows checked.
# 709 of 2477 flows checked.
# 710 of 2477 flows checked.
# 711 of 2477 flows checked.
# 712 of 2477 flows checked.
# 713 of 2477 flows checked.
# 714 of 2477 flows checked.
# 715 of 2477 flows checked.
# 716 of 2477 flows checked.
# 717 of 2477 flows checked.
# 718 of 2477 flows checked.
# 719 of 2477 flows checked.
# 720 of 2477 flows checked.
# 721 of 2477 flows checked.
# 722 of 2477 flows checked.
# 723 of 2477 flows checked.
# 724 of 2477 flows checked.
# 725 of 2477 flows checked.
# 726 of 2477 flows checked.
# 727 of 2477 flows checked.
# 728 of 2477 flows checked.
# 729 of 2477 flows checked.
# 730 of 2477 flows checked.
# 731 of 2477 flows checked.
# 732 of 2477 flows checked.
# 733 of 2477 flows checked.
# 734 of 2477 flows checked.
# 735 of 2477 flows checked.
# 736 of 2477 flows checked.
# 737 of 2477 flows checked.
# 738 of 2477 flows checked.
# 739 of 2477 flows checked.
# 740 of 2477 flows checked.
# 741 of 2477 flows checked.
# 742 of 2477 flows checked.
# 743 of 2477 flows checked.
# 744 of 2477 flows checked.
# 745 of 2477 flows checked.
# 746 of 2477 flows checked.
# 747 of 2477 flows checked.
# 748 of 2477 flows checked.
# 749 of 2477 flows checked.
# 750 of 2477 flows checked.
# 751 of 2477 flows checked.
# 752 of 2477 flows checked.
# 753 of 2477 flows checked.
# 754 of 2477 flows checked.
# 755 of 2477 flows checked.
# 756 of 2477 flows checked.
# 757 of 2477 flows checked.
# 758 of 2477 flows checked.
# 759 of 2477 flows checked.
# 760 of 2477 flows checked.
# 761 of 2477 flows checked.
# 762 of 2477 flows checked.
# 763 of 2477 flows checked.
# 764 of 2477 flows checked.
# 765 of 2477 flows checked.
# 766 of 2477 flows checked.
# 767 of 2477 flows checked.
# 768 of 2477 flows checked.
# 769 of 2477 flows checked.
# 770 of 2477 flows checked.
# 771 of 2477 flows checked.
# 772 of 2477 flows checked.
# 773 of 2477 flows checked.
# 774 of 2477 flows checked.
# 775 of 2477 flows checked.
# 776 of 2477 flows checked.
# 777 of 2477 flows checked.
# 778 of 2477 flows checked.
# 779 of 2477 flows checked.
# 780 of 2477 flows checked.
# 781 of 2477 flows checked.
# 782 of 2477 flows checked.
# 783 of 2477 flows checked.
# 784 of 2477 flows checked.
# 785 of 2477 flows checked.
# 786 of 2477 flows checked.
# 787 of 2477 flows checked.
# 788 of 2477 flows checked.
# 789 of 2477 flows checked.
# 790 of 2477 flows checked.
# 791 of 2477 flows checked.
# 792 of 2477 flows checked.
# 793 of 2477 flows checked.
# 794 of 2477 flows checked.
# 795 of 2477 flows checked.
# 796 of 2477 flows checked.
# 797 of 2477 flows checked.
# 798 of 2477 flows checked.
# 799 of 2477 flows checked.
# 800 of 2477 flows checked.
# 801 of 2477 flows checked.
# 802 of 2477 flows checked.
# 803 of 2477 flows checked.
# 804 of 2477 flows checked.
# 805 of 2477 flows checked.
# 806 of 2477 flows checked.
# 807 of 2477 flows checked.
# 808 of 2477 flows checked.
# 809 of 2477 flows checked.
# 810 of 2477 flows checked.
# 811 of 2477 flows checked.
# 812 of 2477 flows checked.
# 813 of 2477 flows checked.
# 814 of 2477 flows checked.
# 815 of 2477 flows checked.
# 816 of 2477 flows checked.
# 817 of 2477 flows checked.
# 818 of 2477 flows checked.
# 819 of 2477 flows checked.
# 820 of 2477 flows checked.
# 821 of 2477 flows checked.
# 822 of 2477 flows checked.
# 823 of 2477 flows checked.
# 824 of 2477 flows checked.
# 825 of 2477 flows checked.
# 826 of 2477 flows checked.
# 827 of 2477 flows checked.
# 828 of 2477 flows checked.
# 829 of 2477 flows checked.
# 830 of 2477 flows checked.
# 831 of 2477 flows checked.
# 832 of 2477 flows checked.
# 833 of 2477 flows checked.
# 834 of 2477 flows checked.
# 835 of 2477 flows checked.
# 836 of 2477 flows checked.
# 837 of 2477 flows checked.
# 838 of 2477 flows checked.
# 839 of 2477 flows checked.
# 840 of 2477 flows checked.
# 841 of 2477 flows checked.
# 842 of 2477 flows checked.
# 843 of 2477 flows checked.
# 844 of 2477 flows checked.
# 845 of 2477 flows checked.
# 846 of 2477 flows checked.
# 847 of 2477 flows checked.
# 848 of 2477 flows checked.
# 849 of 2477 flows checked.
# 850 of 2477 flows checked.
# 851 of 2477 flows checked.
# 852 of 2477 flows checked.
# 853 of 2477 flows checked.
# 854 of 2477 flows checked.
# 855 of 2477 flows checked.
# 856 of 2477 flows checked.
# 857 of 2477 flows checked.
# 858 of 2477 flows checked.
# 859 of 2477 flows checked.
# 860 of 2477 flows checked.
# 861 of 2477 flows checked.
# 862 of 2477 flows checked.
# 863 of 2477 flows checked.
# 864 of 2477 flows checked.
# 865 of 2477 flows checked.
# 866 of 2477 flows checked.
# 867 of 2477 flows checked.
# 868 of 2477 flows checked.
# 869 of 2477 flows checked.
# 870 of 2477 flows checked.
# 871 of 2477 flows checked.
# 872 of 2477 flows checked.
# 873 of 2477 flows checked.
# 874 of 2477 flows checked.
# 875 of 2477 flows checked.
# 876 of 2477 flows checked.
# 877 of 2477 flows checked.
# 878 of 2477 flows checked.
# 879 of 2477 flows checked.
# 880 of 2477 flows checked.
# 881 of 2477 flows checked.
# 882 of 2477 flows checked.
# 883 of 2477 flows checked.
# 884 of 2477 flows checked.
# 885 of 2477 flows checked.
# 886 of 2477 flows checked.
# 887 of 2477 flows checked.
# 888 of 2477 flows checked.
# 889 of 2477 flows checked.
# 890 of 2477 flows checked.
# 891 of 2477 flows checked.
# 892 of 2477 flows checked.
# 893 of 2477 flows checked.
# 894 of 2477 flows checked.
# 895 of 2477 flows checked.
# 896 of 2477 flows checked.
# 897 of 2477 flows checked.
# 898 of 2477 flows checked.
# 899 of 2477 flows checked.
# 900 of 2477 flows checked.
# 901 of 2477 flows checked.
# 902 of 2477 flows checked.
# 903 of 2477 flows checked.
# 904 of 2477 flows checked.
# 905 of 2477 flows checked.
# 906 of 2477 flows checked.
# 907 of 2477 flows checked.
# 908 of 2477 flows checked.
# 909 of 2477 flows checked.
# 910 of 2477 flows checked.
# 911 of 2477 flows checked.
# 912 of 2477 flows checked.
# 913 of 2477 flows checked.
# 914 of 2477 flows checked.
# 915 of 2477 flows checked.
# 916 of 2477 flows checked.
# 917 of 2477 flows checked.
# 918 of 2477 flows checked.
# 919 of 2477 flows checked.
# 920 of 2477 flows checked.
# 921 of 2477 flows checked.
# 922 of 2477 flows checked.
# 923 of 2477 flows checked.
# 924 of 2477 flows checked.
# 925 of 2477 flows checked.
# 926 of 2477 flows checked.
# 927 of 2477 flows checked.
# 928 of 2477 flows checked.
# 929 of 2477 flows checked.
# 930 of 2477 flows checked.
# 931 of 2477 flows checked.
# 932 of 2477 flows checked.
# 933 of 2477 flows checked.
# 934 of 2477 flows checked.
# 935 of 2477 flows checked.
# 936 of 2477 flows checked.
# 937 of 2477 flows checked.
# 938 of 2477 flows checked.
# 939 of 2477 flows checked.
# 940 of 2477 flows checked.
# 941 of 2477 flows checked.
# 942 of 2477 flows checked.
# 943 of 2477 flows checked.
# 944 of 2477 flows checked.
# 945 of 2477 flows checked.
# 946 of 2477 flows checked.
# 947 of 2477 flows checked.
# 948 of 2477 flows checked.
# 949 of 2477 flows checked.
# 950 of 2477 flows checked.
# 951 of 2477 flows checked.
# 952 of 2477 flows checked.
# 953 of 2477 flows checked.
# 954 of 2477 flows checked.
# 955 of 2477 flows checked.
# 956 of 2477 flows checked.
# 957 of 2477 flows checked.
# 958 of 2477 flows checked.
# 959 of 2477 flows checked.
# 960 of 2477 flows checked.
# 961 of 2477 flows checked.
# 962 of 2477 flows checked.
# 963 of 2477 flows checked.
# 964 of 2477 flows checked.
# 965 of 2477 flows checked.
# 966 of 2477 flows checked.
# 967 of 2477 flows checked.
# 968 of 2477 flows checked.
# 969 of 2477 flows checked.
# 970 of 2477 flows checked.
# 971 of 2477 flows checked.
# 972 of 2477 flows checked.
# 973 of 2477 flows checked.
# 974 of 2477 flows checked.
# 975 of 2477 flows checked.
# 976 of 2477 flows checked.
# 977 of 2477 flows checked.
# 978 of 2477 flows checked.
# 979 of 2477 flows checked.
# 980 of 2477 flows checked.
# 981 of 2477 flows checked.
# 982 of 2477 flows checked.
# 983 of 2477 flows checked.
# 984 of 2477 flows checked.
# 985 of 2477 flows checked.
# 986 of 2477 flows checked.
# 987 of 2477 flows checked.
# 988 of 2477 flows checked.
# 989 of 2477 flows checked.
# 990 of 2477 flows checked.
# 991 of 2477 flows checked.
# 992 of 2477 flows checked.
# 993 of 2477 flows checked.
# 994 of 2477 flows checked.
# 995 of 2477 flows checked.
# 996 of 2477 flows checked.
# 997 of 2477 flows checked.
# 998 of 2477 flows checked.
# 999 of 2477 flows checked.
# 1000 of 2477 flows checked.
# 1001 of 2477 flows checked.
# 1002 of 2477 flows checked.
# 1003 of 2477 flows checked.
# 1004 of 2477 flows checked.
# 1005 of 2477 flows checked.
# 1006 of 2477 flows checked.
# 1007 of 2477 flows checked.
# 1008 of 2477 flows checked.
# 1009 of 2477 flows checked.
# 1010 of 2477 flows checked.
# 1011 of 2477 flows checked.
# 1012 of 2477 flows checked.
# 1013 of 2477 flows checked.
# 1014 of 2477 flows checked.
# 1015 of 2477 flows checked.
# 1016 of 2477 flows checked.
# 1017 of 2477 flows checked.
# 1018 of 2477 flows checked.
# 1019 of 2477 flows checked.
# 1020 of 2477 flows checked.
# 1021 of 2477 flows checked.
# 1022 of 2477 flows checked.
# 1023 of 2477 flows checked.
# 1024 of 2477 flows checked.
# 1025 of 2477 flows checked.
# 1026 of 2477 flows checked.
# 1027 of 2477 flows checked.
# 1028 of 2477 flows checked.
# 1029 of 2477 flows checked.
# 1030 of 2477 flows checked.
# 1031 of 2477 flows checked.
# 1032 of 2477 flows checked.
# 1033 of 2477 flows checked.
# 1034 of 2477 flows checked.
# 1035 of 2477 flows checked.
# 1036 of 2477 flows checked.
# 1037 of 2477 flows checked.
# 1038 of 2477 flows checked.
# 1039 of 2477 flows checked.
# 1040 of 2477 flows checked.
# 1041 of 2477 flows checked.
# 1042 of 2477 flows checked.
# 1043 of 2477 flows checked.
# 1044 of 2477 flows checked.
# 1045 of 2477 flows checked.
# 1046 of 2477 flows checked.
# 1047 of 2477 flows checked.
# 1048 of 2477 flows checked.
# 1049 of 2477 flows checked.
# 1050 of 2477 flows checked.
# 1051 of 2477 flows checked.
# 1052 of 2477 flows checked.
# 1053 of 2477 flows checked.
# 1054 of 2477 flows checked.
# 1055 of 2477 flows checked.
# 1056 of 2477 flows checked.
# 1057 of 2477 flows checked.
# 1058 of 2477 flows checked.
# 1059 of 2477 flows checked.
# 1060 of 2477 flows checked.
# 1061 of 2477 flows checked.
# 1062 of 2477 flows checked.
# 1063 of 2477 flows checked.
# 1064 of 2477 flows checked.
# 1065 of 2477 flows checked.
# 1066 of 2477 flows checked.
# 1067 of 2477 flows checked.
# 1068 of 2477 flows checked.
# 1069 of 2477 flows checked.
# 1070 of 2477 flows checked.
# 1071 of 2477 flows checked.
# 1072 of 2477 flows checked.
# 1073 of 2477 flows checked.
# 1074 of 2477 flows checked.
# 1075 of 2477 flows checked.
# 1076 of 2477 flows checked.
# 1077 of 2477 flows checked.
# 1078 of 2477 flows checked.
# 1079 of 2477 flows checked.
# 1080 of 2477 flows checked.
# 1081 of 2477 flows checked.
# 1082 of 2477 flows checked.
# 1083 of 2477 flows checked.
# 1084 of 2477 flows checked.
# 1085 of 2477 flows checked.
# 1086 of 2477 flows checked.
# 1087 of 2477 flows checked.
# 1088 of 2477 flows checked.
# 1089 of 2477 flows checked.
# 1090 of 2477 flows checked.
# 1091 of 2477 flows checked.
# 1092 of 2477 flows checked.
# 1093 of 2477 flows checked.
# 1094 of 2477 flows checked.
# 1095 of 2477 flows checked.
# 1096 of 2477 flows checked.
# 1097 of 2477 flows checked.
# 1098 of 2477 flows checked.
# 1099 of 2477 flows checked.
# 1100 of 2477 flows checked.
# 1101 of 2477 flows checked.
# 1102 of 2477 flows checked.
# 1103 of 2477 flows checked.
# 1104 of 2477 flows checked.
# 1105 of 2477 flows checked.
# 1106 of 2477 flows checked.
# 1107 of 2477 flows checked.
# 1108 of 2477 flows checked.
# 1109 of 2477 flows checked.
# 1110 of 2477 flows checked.
# 1111 of 2477 flows checked.
# 1112 of 2477 flows checked.
# 1113 of 2477 flows checked.
# 1114 of 2477 flows checked.
# 1115 of 2477 flows checked.
# 1116 of 2477 flows checked.
# 1117 of 2477 flows checked.
# 1118 of 2477 flows checked.
# 1119 of 2477 flows checked.
# 1120 of 2477 flows checked.
# 1121 of 2477 flows checked.
# 1122 of 2477 flows checked.
# 1123 of 2477 flows checked.
# 1124 of 2477 flows checked.
# 1125 of 2477 flows checked.
# 1126 of 2477 flows checked.
# 1127 of 2477 flows checked.
# 1128 of 2477 flows checked.
# 1129 of 2477 flows checked.
# 1130 of 2477 flows checked.
# 1131 of 2477 flows checked.
# 1132 of 2477 flows checked.
# 1133 of 2477 flows checked.
# 1134 of 2477 flows checked.
# 1135 of 2477 flows checked.
# 1136 of 2477 flows checked.
# 1137 of 2477 flows checked.
# 1138 of 2477 flows checked.
# 1139 of 2477 flows checked.
# 1140 of 2477 flows checked.
# 1141 of 2477 flows checked.
# 1142 of 2477 flows checked.
# 1143 of 2477 flows checked.
# 1144 of 2477 flows checked.
# 1145 of 2477 flows checked.
# 1146 of 2477 flows checked.
# 1147 of 2477 flows checked.
# 1148 of 2477 flows checked.
# 1149 of 2477 flows checked.
# 1150 of 2477 flows checked.
# 1151 of 2477 flows checked.
# 1152 of 2477 flows checked.
# 1153 of 2477 flows checked.
# 1154 of 2477 flows checked.
# 1155 of 2477 flows checked.
# 1156 of 2477 flows checked.
# 1157 of 2477 flows checked.
# 1158 of 2477 flows checked.
# 1159 of 2477 flows checked.
# 1160 of 2477 flows checked.
# 1161 of 2477 flows checked.
# 1162 of 2477 flows checked.
# 1163 of 2477 flows checked.
# 1164 of 2477 flows checked.
# 1165 of 2477 flows checked.
# 1166 of 2477 flows checked.
# 1167 of 2477 flows checked.
# 1168 of 2477 flows checked.
# 1169 of 2477 flows checked.
# 1170 of 2477 flows checked.
# 1171 of 2477 flows checked.
# 1172 of 2477 flows checked.
# 1173 of 2477 flows checked.
# 1174 of 2477 flows checked.
# 1175 of 2477 flows checked.
# 1176 of 2477 flows checked.
# 1177 of 2477 flows checked.
# 1178 of 2477 flows checked.
# 1179 of 2477 flows checked.
# 1180 of 2477 flows checked.
# 1181 of 2477 flows checked.
# 1182 of 2477 flows checked.
# 1183 of 2477 flows checked.
# 1184 of 2477 flows checked.
# 1185 of 2477 flows checked.
# 1186 of 2477 flows checked.
# 1187 of 2477 flows checked.
# 1188 of 2477 flows checked.
# 1189 of 2477 flows checked.
# 1190 of 2477 flows checked.
# 1191 of 2477 flows checked.
# 1192 of 2477 flows checked.
# 1193 of 2477 flows checked.
# 1194 of 2477 flows checked.
# 1195 of 2477 flows checked.
# 1196 of 2477 flows checked.
# 1197 of 2477 flows checked.
# 1198 of 2477 flows checked.
# 1199 of 2477 flows checked.
# 1200 of 2477 flows checked.
# 1201 of 2477 flows checked.
# 1202 of 2477 flows checked.
# 1203 of 2477 flows checked.
# 1204 of 2477 flows checked.
# 1205 of 2477 flows checked.
# 1206 of 2477 flows checked.
# 1207 of 2477 flows checked.
# 1208 of 2477 flows checked.
# 1209 of 2477 flows checked.
# 1210 of 2477 flows checked.
# 1211 of 2477 flows checked.
# 1212 of 2477 flows checked.
# 1213 of 2477 flows checked.
# 1214 of 2477 flows checked.
# 1215 of 2477 flows checked.
# 1216 of 2477 flows checked.
# 1217 of 2477 flows checked.
# 1218 of 2477 flows checked.
# 1219 of 2477 flows checked.
# 1220 of 2477 flows checked.
# 1221 of 2477 flows checked.
# 1222 of 2477 flows checked.
# 1223 of 2477 flows checked.
# 1224 of 2477 flows checked.
# 1225 of 2477 flows checked.
# 1226 of 2477 flows checked.
# 1227 of 2477 flows checked.
# 1228 of 2477 flows checked.
# 1229 of 2477 flows checked.
# 1230 of 2477 flows checked.
# 1231 of 2477 flows checked.
# 1232 of 2477 flows checked.
# 1233 of 2477 flows checked.
# 1234 of 2477 flows checked.
# 1235 of 2477 flows checked.
# 1236 of 2477 flows checked.
# 1237 of 2477 flows checked.
# 1238 of 2477 flows checked.
# 1239 of 2477 flows checked.
# 1240 of 2477 flows checked.
# 1241 of 2477 flows checked.
# 1242 of 2477 flows checked.
# 1243 of 2477 flows checked.
# 1244 of 2477 flows checked.
# 1245 of 2477 flows checked.
# 1246 of 2477 flows checked.
# 1247 of 2477 flows checked.
# 1248 of 2477 flows checked.
# 1249 of 2477 flows checked.
# 1250 of 2477 flows checked.
# 1251 of 2477 flows checked.
# 1252 of 2477 flows checked.
# 1253 of 2477 flows checked.
# 1254 of 2477 flows checked.
# 1255 of 2477 flows checked.
# 1256 of 2477 flows checked.
# 1257 of 2477 flows checked.
# 1258 of 2477 flows checked.
# 1259 of 2477 flows checked.
# 1260 of 2477 flows checked.
# 1261 of 2477 flows checked.
# 1262 of 2477 flows checked.
# 1263 of 2477 flows checked.
# 1264 of 2477 flows checked.
# 1265 of 2477 flows checked.
# 1266 of 2477 flows checked.
# 1267 of 2477 flows checked.
# 1268 of 2477 flows checked.
# 1269 of 2477 flows checked.
# 1270 of 2477 flows checked.
# 1271 of 2477 flows checked.
# 1272 of 2477 flows checked.
# 1273 of 2477 flows checked.
# 1274 of 2477 flows checked.
# 1275 of 2477 flows checked.
# 1276 of 2477 flows checked.
# 1277 of 2477 flows checked.
# 1278 of 2477 flows checked.
# 1279 of 2477 flows checked.
# 1280 of 2477 flows checked.
# 1281 of 2477 flows checked.
# 1282 of 2477 flows checked.
# 1283 of 2477 flows checked.
# 1284 of 2477 flows checked.
# 1285 of 2477 flows checked.
# 1286 of 2477 flows checked.
# 1287 of 2477 flows checked.
# 1288 of 2477 flows checked.
# 1289 of 2477 flows checked.
# 1290 of 2477 flows checked.
# 1291 of 2477 flows checked.
# 1292 of 2477 flows checked.
# 1293 of 2477 flows checked.
# 1294 of 2477 flows checked.
# 1295 of 2477 flows checked.
# 1296 of 2477 flows checked.
# 1297 of 2477 flows checked.
# 1298 of 2477 flows checked.
# 1299 of 2477 flows checked.
# 1300 of 2477 flows checked.
# 1301 of 2477 flows checked.
# 1302 of 2477 flows checked.
# 1303 of 2477 flows checked.
# 1304 of 2477 flows checked.
# 1305 of 2477 flows checked.
# 1306 of 2477 flows checked.
# 1307 of 2477 flows checked.
# 1308 of 2477 flows checked.
# 1309 of 2477 flows checked.
# 1310 of 2477 flows checked.
# 1311 of 2477 flows checked.
# 1312 of 2477 flows checked.
# 1313 of 2477 flows checked.
# 1314 of 2477 flows checked.
# 1315 of 2477 flows checked.
# 1316 of 2477 flows checked.
# 1317 of 2477 flows checked.
# 1318 of 2477 flows checked.
# 1319 of 2477 flows checked.
# 1320 of 2477 flows checked.
# 1321 of 2477 flows checked.
# 1322 of 2477 flows checked.
# 1323 of 2477 flows checked.
# 1324 of 2477 flows checked.
# 1325 of 2477 flows checked.
# 1326 of 2477 flows checked.
# 1327 of 2477 flows checked.
# 1328 of 2477 flows checked.
# 1329 of 2477 flows checked.
# 1330 of 2477 flows checked.
# 1331 of 2477 flows checked.
# 1332 of 2477 flows checked.
# 1333 of 2477 flows checked.
# 1334 of 2477 flows checked.
# 1335 of 2477 flows checked.
# 1336 of 2477 flows checked.
# 1337 of 2477 flows checked.
# 1338 of 2477 flows checked.
# 1339 of 2477 flows checked.
# 1340 of 2477 flows checked.
# 1341 of 2477 flows checked.
# 1342 of 2477 flows checked.
# 1343 of 2477 flows checked.
# 1344 of 2477 flows checked.
# 1345 of 2477 flows checked.
# 1346 of 2477 flows checked.
# 1347 of 2477 flows checked.
# 1348 of 2477 flows checked.
# 1349 of 2477 flows checked.
# 1350 of 2477 flows checked.
# 1351 of 2477 flows checked.
# 1352 of 2477 flows checked.
# 1353 of 2477 flows checked.
# 1354 of 2477 flows checked.
# 1355 of 2477 flows checked.
# 1356 of 2477 flows checked.
# 1357 of 2477 flows checked.
# 1358 of 2477 flows checked.
# 1359 of 2477 flows checked.
# 1360 of 2477 flows checked.
# 1361 of 2477 flows checked.
# 1362 of 2477 flows checked.
# 1363 of 2477 flows checked.
# 1364 of 2477 flows checked.
# 1365 of 2477 flows checked.
# 1366 of 2477 flows checked.
# 1367 of 2477 flows checked.
# 1368 of 2477 flows checked.
# 1369 of 2477 flows checked.
# 1370 of 2477 flows checked.
# 1371 of 2477 flows checked.
# 1372 of 2477 flows checked.
# 1373 of 2477 flows checked.
# 1374 of 2477 flows checked.
# 1375 of 2477 flows checked.
# 1376 of 2477 flows checked.
# 1377 of 2477 flows checked.
# 1378 of 2477 flows checked.
# 1379 of 2477 flows checked.
# 1380 of 2477 flows checked.
# 1381 of 2477 flows checked.
# 1382 of 2477 flows checked.
# 1383 of 2477 flows checked.
# 1384 of 2477 flows checked.
# 1385 of 2477 flows checked.
# 1386 of 2477 flows checked.
# 1387 of 2477 flows checked.
# 1388 of 2477 flows checked.
# 1389 of 2477 flows checked.
# 1390 of 2477 flows checked.
# 1391 of 2477 flows checked.
# 1392 of 2477 flows checked.
# 1393 of 2477 flows checked.
# 1394 of 2477 flows checked.
# 1395 of 2477 flows checked.
# 1396 of 2477 flows checked.
# 1397 of 2477 flows checked.
# 1398 of 2477 flows checked.
# 1399 of 2477 flows checked.
# 1400 of 2477 flows checked.
# 1401 of 2477 flows checked.
# 1402 of 2477 flows checked.
# 1403 of 2477 flows checked.
# 1404 of 2477 flows checked.
# 1405 of 2477 flows checked.
# 1406 of 2477 flows checked.
# 1407 of 2477 flows checked.
# 1408 of 2477 flows checked.
# 1409 of 2477 flows checked.
# 1410 of 2477 flows checked.
# 1411 of 2477 flows checked.
# 1412 of 2477 flows checked.
# 1413 of 2477 flows checked.
# 1414 of 2477 flows checked.
# 1415 of 2477 flows checked.
# 1416 of 2477 flows checked.
# 1417 of 2477 flows checked.
# 1418 of 2477 flows checked.
# 1419 of 2477 flows checked.
# 1420 of 2477 flows checked.
# 1421 of 2477 flows checked.
# 1422 of 2477 flows checked.
# 1423 of 2477 flows checked.
# 1424 of 2477 flows checked.
# 1425 of 2477 flows checked.
# 1426 of 2477 flows checked.
# 1427 of 2477 flows checked.
# 1428 of 2477 flows checked.
# 1429 of 2477 flows checked.
# 1430 of 2477 flows checked.
# 1431 of 2477 flows checked.
# 1432 of 2477 flows checked.
# 1433 of 2477 flows checked.
# 1434 of 2477 flows checked.
# 1435 of 2477 flows checked.
# 1436 of 2477 flows checked.
# 1437 of 2477 flows checked.
# 1438 of 2477 flows checked.
# 1439 of 2477 flows checked.
# 1440 of 2477 flows checked.
# 1441 of 2477 flows checked.
# 1442 of 2477 flows checked.
# 1443 of 2477 flows checked.
# 1444 of 2477 flows checked.
# 1445 of 2477 flows checked.
# 1446 of 2477 flows checked.
# 1447 of 2477 flows checked.
# 1448 of 2477 flows checked.
# 1449 of 2477 flows checked.
# 1450 of 2477 flows checked.
# 1451 of 2477 flows checked.
# 1452 of 2477 flows checked.
# 1453 of 2477 flows checked.
# 1454 of 2477 flows checked.
# 1455 of 2477 flows checked.
# 1456 of 2477 flows checked.
# 1457 of 2477 flows checked.
# 1458 of 2477 flows checked.
# 1459 of 2477 flows checked.
# 1460 of 2477 flows checked.
# 1461 of 2477 flows checked.
# 1462 of 2477 flows checked.
# 1463 of 2477 flows checked.
# 1464 of 2477 flows checked.
# 1465 of 2477 flows checked.
# 1466 of 2477 flows checked.
# 1467 of 2477 flows checked.
# 1468 of 2477 flows checked.
# 1469 of 2477 flows checked.
# 1470 of 2477 flows checked.
# 1471 of 2477 flows checked.
# 1472 of 2477 flows checked.
# 1473 of 2477 flows checked.
# 1474 of 2477 flows checked.
# 1475 of 2477 flows checked.
# 1476 of 2477 flows checked.
# 1477 of 2477 flows checked.
# 1478 of 2477 flows checked.
# 1479 of 2477 flows checked.
# 1480 of 2477 flows checked.
# 1481 of 2477 flows checked.
# 1482 of 2477 flows checked.
# 1483 of 2477 flows checked.
# 1484 of 2477 flows checked.
# 1485 of 2477 flows checked.
# 1486 of 2477 flows checked.
# 1487 of 2477 flows checked.
# 1488 of 2477 flows checked.
# 1489 of 2477 flows checked.
# 1490 of 2477 flows checked.
# 1491 of 2477 flows checked.
# 1492 of 2477 flows checked.
# 1493 of 2477 flows checked.
# 1494 of 2477 flows checked.
# 1495 of 2477 flows checked.
# 1496 of 2477 flows checked.
# 1497 of 2477 flows checked.
# 1498 of 2477 flows checked.
# 1499 of 2477 flows checked.
# 1500 of 2477 flows checked.
# 1501 of 2477 flows checked.
# 1502 of 2477 flows checked.
# 1503 of 2477 flows checked.
# 1504 of 2477 flows checked.
# 1505 of 2477 flows checked.
# 1506 of 2477 flows checked.
# 1507 of 2477 flows checked.
# 1508 of 2477 flows checked.
# 1509 of 2477 flows checked.
# 1510 of 2477 flows checked.
# 1511 of 2477 flows checked.
# 1512 of 2477 flows checked.
# 1513 of 2477 flows checked.
# 1514 of 2477 flows checked.
# 1515 of 2477 flows checked.
# 1516 of 2477 flows checked.
# 1517 of 2477 flows checked.
# 1518 of 2477 flows checked.
# 1519 of 2477 flows checked.
# 1520 of 2477 flows checked.
# 1521 of 2477 flows checked.
# 1522 of 2477 flows checked.
# 1523 of 2477 flows checked.
# 1524 of 2477 flows checked.
# 1525 of 2477 flows checked.
# 1526 of 2477 flows checked.
# 1527 of 2477 flows checked.
# 1528 of 2477 flows checked.
# 1529 of 2477 flows checked.
# 1530 of 2477 flows checked.
# 1531 of 2477 flows checked.
# 1532 of 2477 flows checked.
# 1533 of 2477 flows checked.
# 1534 of 2477 flows checked.
# 1535 of 2477 flows checked.
# 1536 of 2477 flows checked.
# 1537 of 2477 flows checked.
# 1538 of 2477 flows checked.
# 1539 of 2477 flows checked.
# 1540 of 2477 flows checked.
# 1541 of 2477 flows checked.
# 1542 of 2477 flows checked.
# 1543 of 2477 flows checked.
# 1544 of 2477 flows checked.
# 1545 of 2477 flows checked.
# 1546 of 2477 flows checked.
# 1547 of 2477 flows checked.
# 1548 of 2477 flows checked.
# 1549 of 2477 flows checked.
# 1550 of 2477 flows checked.
# 1551 of 2477 flows checked.
# 1552 of 2477 flows checked.
# 1553 of 2477 flows checked.
# 1554 of 2477 flows checked.
# 1555 of 2477 flows checked.
# 1556 of 2477 flows checked.
# 1557 of 2477 flows checked.
# 1558 of 2477 flows checked.
# 1559 of 2477 flows checked.
# 1560 of 2477 flows checked.
# 1561 of 2477 flows checked.
# 1562 of 2477 flows checked.
# 1563 of 2477 flows checked.
# 1564 of 2477 flows checked.
# 1565 of 2477 flows checked.
# 1566 of 2477 flows checked.
# 1567 of 2477 flows checked.
# 1568 of 2477 flows checked.
# 1569 of 2477 flows checked.
# 1570 of 2477 flows checked.
# 1571 of 2477 flows checked.
# 1572 of 2477 flows checked.
# 1573 of 2477 flows checked.
# 1574 of 2477 flows checked.
# 1575 of 2477 flows checked.
# 1576 of 2477 flows checked.
# 1577 of 2477 flows checked.
# 1578 of 2477 flows checked.
# 1579 of 2477 flows checked.
# 1580 of 2477 flows checked.
# 1581 of 2477 flows checked.
# 1582 of 2477 flows checked.
# 1583 of 2477 flows checked.
# 1584 of 2477 flows checked.
# 1585 of 2477 flows checked.
# 1586 of 2477 flows checked.
# 1587 of 2477 flows checked.
# 1588 of 2477 flows checked.
# 1589 of 2477 flows checked.
# 1590 of 2477 flows checked.
# 1591 of 2477 flows checked.
# 1592 of 2477 flows checked.
# 1593 of 2477 flows checked.
# 1594 of 2477 flows checked.
# 1595 of 2477 flows checked.
# 1596 of 2477 flows checked.
# 1597 of 2477 flows checked.
# 1598 of 2477 flows checked.
# 1599 of 2477 flows checked.
# 1600 of 2477 flows checked.
# 1601 of 2477 flows checked.
# 1602 of 2477 flows checked.
# 1603 of 2477 flows checked.
# 1604 of 2477 flows checked.
# 1605 of 2477 flows checked.
# 1606 of 2477 flows checked.
# 1607 of 2477 flows checked.
# 1608 of 2477 flows checked.
# 1609 of 2477 flows checked.
# 1610 of 2477 flows checked.
# 1611 of 2477 flows checked.
# 1612 of 2477 flows checked.
# 1613 of 2477 flows checked.
# 1614 of 2477 flows checked.
# 1615 of 2477 flows checked.
# 1616 of 2477 flows checked.
# 1617 of 2477 flows checked.
# 1618 of 2477 flows checked.
# 1619 of 2477 flows checked.
# 1620 of 2477 flows checked.
# 1621 of 2477 flows checked.
# 1622 of 2477 flows checked.
# 1623 of 2477 flows checked.
# 1624 of 2477 flows checked.
# 1625 of 2477 flows checked.
# 1626 of 2477 flows checked.
# 1627 of 2477 flows checked.
# 1628 of 2477 flows checked.
# 1629 of 2477 flows checked.
# 1630 of 2477 flows checked.
# 1631 of 2477 flows checked.
# 1632 of 2477 flows checked.
# 1633 of 2477 flows checked.
# 1634 of 2477 flows checked.
# 1635 of 2477 flows checked.
# 1636 of 2477 flows checked.
# 1637 of 2477 flows checked.
# 1638 of 2477 flows checked.
# 1639 of 2477 flows checked.
# 1640 of 2477 flows checked.
# 1641 of 2477 flows checked.
# 1642 of 2477 flows checked.
# 1643 of 2477 flows checked.
# 1644 of 2477 flows checked.
# 1645 of 2477 flows checked.
# 1646 of 2477 flows checked.
# 1647 of 2477 flows checked.
# 1648 of 2477 flows checked.
# 1649 of 2477 flows checked.
# 1650 of 2477 flows checked.
# 1651 of 2477 flows checked.
# 1652 of 2477 flows checked.
# 1653 of 2477 flows checked.
# 1654 of 2477 flows checked.
# 1655 of 2477 flows checked.
# 1656 of 2477 flows checked.
# 1657 of 2477 flows checked.
# 1658 of 2477 flows checked.
# 1659 of 2477 flows checked.
# 1660 of 2477 flows checked.
# 1661 of 2477 flows checked.
# 1662 of 2477 flows checked.
# 1663 of 2477 flows checked.
# 1664 of 2477 flows checked.
# 1665 of 2477 flows checked.
# 1666 of 2477 flows checked.
# 1667 of 2477 flows checked.
# 1668 of 2477 flows checked.
# 1669 of 2477 flows checked.
# 1670 of 2477 flows checked.
# 1671 of 2477 flows checked.
# 1672 of 2477 flows checked.
# 1673 of 2477 flows checked.
# 1674 of 2477 flows checked.
# 1675 of 2477 flows checked.
# 1676 of 2477 flows checked.
# 1677 of 2477 flows checked.
# 1678 of 2477 flows checked.
# 1679 of 2477 flows checked.
# 1680 of 2477 flows checked.
# 1681 of 2477 flows checked.
# 1682 of 2477 flows checked.
# 1683 of 2477 flows checked.
# 1684 of 2477 flows checked.
# 1685 of 2477 flows checked.
# 1686 of 2477 flows checked.
# 1687 of 2477 flows checked.
# 1688 of 2477 flows checked.
# 1689 of 2477 flows checked.
# 1690 of 2477 flows checked.
# 1691 of 2477 flows checked.
# 1692 of 2477 flows checked.
# 1693 of 2477 flows checked.
# 1694 of 2477 flows checked.
# 1695 of 2477 flows checked.
# 1696 of 2477 flows checked.
# 1697 of 2477 flows checked.
# 1698 of 2477 flows checked.
# 1699 of 2477 flows checked.
# 1700 of 2477 flows checked.
# 1701 of 2477 flows checked.
# 1702 of 2477 flows checked.
# 1703 of 2477 flows checked.
# 1704 of 2477 flows checked.
# 1705 of 2477 flows checked.
# 1706 of 2477 flows checked.
# 1707 of 2477 flows checked.
# 1708 of 2477 flows checked.
# 1709 of 2477 flows checked.
# 1710 of 2477 flows checked.
# 1711 of 2477 flows checked.
# 1712 of 2477 flows checked.
# 1713 of 2477 flows checked.
# 1714 of 2477 flows checked.
# 1715 of 2477 flows checked.
# 1716 of 2477 flows checked.
# 1717 of 2477 flows checked.
# 1718 of 2477 flows checked.
# 1719 of 2477 flows checked.
# 1720 of 2477 flows checked.
# 1721 of 2477 flows checked.
# 1722 of 2477 flows checked.
# 1723 of 2477 flows checked.
# 1724 of 2477 flows checked.
# 1725 of 2477 flows checked.
# 1726 of 2477 flows checked.
# 1727 of 2477 flows checked.
# 1728 of 2477 flows checked.
# 1729 of 2477 flows checked.
# 1730 of 2477 flows checked.
# 1731 of 2477 flows checked.
# 1732 of 2477 flows checked.
# 1733 of 2477 flows checked.
# 1734 of 2477 flows checked.
# 1735 of 2477 flows checked.
# 1736 of 2477 flows checked.
# 1737 of 2477 flows checked.
# 1738 of 2477 flows checked.
# 1739 of 2477 flows checked.
# 1740 of 2477 flows checked.
# 1741 of 2477 flows checked.
# 1742 of 2477 flows checked.
# 1743 of 2477 flows checked.
# 1744 of 2477 flows checked.
# 1745 of 2477 flows checked.
# 1746 of 2477 flows checked.
# 1747 of 2477 flows checked.
# 1748 of 2477 flows checked.
# 1749 of 2477 flows checked.
# 1750 of 2477 flows checked.
# 1751 of 2477 flows checked.
# 1752 of 2477 flows checked.
# 1753 of 2477 flows checked.
# ...
# 1907 of 2477 flows checked.
# 1908 of 2477 flows checked.
# 1909 of 2477 flows checked.
# 1910 of 2477 flows checked.
# 1911 of 2477 flows checked.
# 1912 of 2477 flows checked.
# 1913 of 2477 flows checked.
# 1914 of 2477 flows checked.
# 1915 of 2477 flows checked.
# 1916 of 2477 flows checked.
# 1917 of 2477 flows checked.
# 1918 of 2477 flows checked.
# 1919 of 2477 flows checked.
# 1920 of 2477 flows checked.
# 1921 of 2477 flows checked.
# 1922 of 2477 flows checked.
# 1923 of 2477 flows checked.
# 1924 of 2477 flows checked.
# 1925 of 2477 flows checked.
# 1926 of 2477 flows checked.
# 1927 of 2477 flows checked.
# 1928 of 2477 flows checked.
# 1929 of 2477 flows checked.
# 1930 of 2477 flows checked.
# 1931 of 2477 flows checked.
# 1932 of 2477 flows checked.
# 1933 of 2477 flows checked.
# 1934 of 2477 flows checked.
# 1935 of 2477 flows checked.
# 1936 of 2477 flows checked.
# 1937 of 2477 flows checked.
# 1938 of 2477 flows checked.
# 1939 of 2477 flows checked.
# 1940 of 2477 flows checked.
# 1941 of 2477 flows checked.
# 1942 of 2477 flows checked.
# 1943 of 2477 flows checked.
# 1944 of 2477 flows checked.
# 1945 of 2477 flows checked.
# 1946 of 2477 flows checked.
# 1947 of 2477 flows checked.
# 1948 of 2477 flows checked.
# 1949 of 2477 flows checked.
# 1950 of 2477 flows checked.
# 1951 of 2477 flows checked.
# 1952 of 2477 flows checked.
# 1953 of 2477 flows checked.
# 1954 of 2477 flows checked.
# 1955 of 2477 flows checked.
# 1956 of 2477 flows checked.
# 1957 of 2477 flows checked.
# 1958 of 2477 flows checked.
# 1959 of 2477 flows checked.
# 1960 of 2477 flows checked.
# 1961 of 2477 flows checked.
# 1962 of 2477 flows checked.
# 1963 of 2477 flows checked.
# 1964 of 2477 flows checked.
# 1965 of 2477 flows checked.
# 1966 of 2477 flows checked.
# 1967 of 2477 flows checked.
# 1968 of 2477 flows checked.
# 1969 of 2477 flows checked.
# 1970 of 2477 flows checked.
# 1971 of 2477 flows checked.
# 1972 of 2477 flows checked.
# 1973 of 2477 flows checked.
# 1974 of 2477 flows checked.
# 1975 of 2477 flows checked.
# 1976 of 2477 flows checked.
# 1977 of 2477 flows checked.
# 1978 of 2477 flows checked.
# 1979 of 2477 flows checked.
# 1980 of 2477 flows checked.
# 1981 of 2477 flows checked.
# 1982 of 2477 flows checked.
# 1983 of 2477 flows checked.
# 1984 of 2477 flows checked.
# 1985 of 2477 flows checked.
# 1986 of 2477 flows checked.
# 1987 of 2477 flows checked.
# 1988 of 2477 flows checked.
# 1989 of 2477 flows checked.
# 1990 of 2477 flows checked.
# 1991 of 2477 flows checked.
# 1992 of 2477 flows checked.
# 1993 of 2477 flows checked.
# 1994 of 2477 flows checked.
# 1995 of 2477 flows checked.
# 1996 of 2477 flows checked.
# 1997 of 2477 flows checked.
# 1998 of 2477 flows checked.
# 1999 of 2477 flows checked.
# 2000 of 2477 flows checked.
# 2001 of 2477 flows checked.
# 2002 of 2477 flows checked.
# 2003 of 2477 flows checked.
# 2004 of 2477 flows checked.
# 2005 of 2477 flows checked.
# 2006 of 2477 flows checked.
# 2007 of 2477 flows checked.
# 2008 of 2477 flows checked.
# 2009 of 2477 flows checked.
# 2010 of 2477 flows checked.
# 2011 of 2477 flows checked.
# 2012 of 2477 flows checked.
# 2013 of 2477 flows checked.
# 2014 of 2477 flows checked.
# 2015 of 2477 flows checked.
# 2016 of 2477 flows checked.
# 2017 of 2477 flows checked.
# 2018 of 2477 flows checked.
# 2019 of 2477 flows checked.
# 2020 of 2477 flows checked.
# 2021 of 2477 flows checked.
# 2022 of 2477 flows checked.
# 2023 of 2477 flows checked.
# 2024 of 2477 flows checked.
# 2025 of 2477 flows checked.
# 2026 of 2477 flows checked.
# 2027 of 2477 flows checked.
# 2028 of 2477 flows checked.
# 2029 of 2477 flows checked.
# 2030 of 2477 flows checked.
# 2031 of 2477 flows checked.
# 2032 of 2477 flows checked.
# 2033 of 2477 flows checked.
# 2034 of 2477 flows checked.
# 2035 of 2477 flows checked.
# 2036 of 2477 flows checked.
# 2037 of 2477 flows checked.
# 2038 of 2477 flows checked.
# 2039 of 2477 flows checked.
# 2040 of 2477 flows checked.
# 2041 of 2477 flows checked.
# 2042 of 2477 flows checked.
# 2043 of 2477 flows checked.
# 2044 of 2477 flows checked.
# 2045 of 2477 flows checked.
# 2046 of 2477 flows checked.
# 2047 of 2477 flows checked.
# 2048 of 2477 flows checked.
# 2049 of 2477 flows checked.
# 2050 of 2477 flows checked.
# 2051 of 2477 flows checked.
# 2052 of 2477 flows checked.
# 2053 of 2477 flows checked.
# 2054 of 2477 flows checked.
# 2055 of 2477 flows checked.
# 2056 of 2477 flows checked.
# 2057 of 2477 flows checked.
# 2058 of 2477 flows checked.
# 2059 of 2477 flows checked.
# 2060 of 2477 flows checked.
# 2061 of 2477 flows checked.
# 2062 of 2477 flows checked.
# 2063 of 2477 flows checked.
# 2064 of 2477 flows checked.
# 2065 of 2477 flows checked.
# 2066 of 2477 flows checked.
# 2067 of 2477 flows checked.
# 2068 of 2477 flows checked.
# 2069 of 2477 flows checked.
# 2070 of 2477 flows checked.
# 2071 of 2477 flows checked.
# 2072 of 2477 flows checked.
# 2073 of 2477 flows checked.
# 2074 of 2477 flows checked.
# 2075 of 2477 flows checked.
# 2076 of 2477 flows checked.
# 2077 of 2477 flows checked.
# 2078 of 2477 flows checked.
# 2079 of 2477 flows checked.
# 2080 of 2477 flows checked.
# 2081 of 2477 flows checked.
# 2082 of 2477 flows checked.
# 2083 of 2477 flows checked.
# 2084 of 2477 flows checked.
# 2085 of 2477 flows checked.
# 2086 of 2477 flows checked.
# 2087 of 2477 flows checked.
# 2088 of 2477 flows checked.
# 2089 of 2477 flows checked.
# 2090 of 2477 flows checked.
# 2091 of 2477 flows checked.
# 2092 of 2477 flows checked.
# 2093 of 2477 flows checked.
# 2094 of 2477 flows checked.
# 2095 of 2477 flows checked.
# 2096 of 2477 flows checked.
# 2097 of 2477 flows checked.
# 2098 of 2477 flows checked.
# 2099 of 2477 flows checked.
# 2100 of 2477 flows checked.
# 2101 of 2477 flows checked.
# 2102 of 2477 flows checked.
# 2103 of 2477 flows checked.
# 2104 of 2477 flows checked.
# 2105 of 2477 flows checked.
# 2106 of 2477 flows checked.
# 2107 of 2477 flows checked.
# 2108 of 2477 flows checked.
# 2109 of 2477 flows checked.
# 2110 of 2477 flows checked.
# 2111 of 2477 flows checked.
# 2112 of 2477 flows checked.
# 2113 of 2477 flows checked.
# 2114 of 2477 flows checked.
# 2115 of 2477 flows checked.
# 2116 of 2477 flows checked.
# 2117 of 2477 flows checked.
# 2118 of 2477 flows checked.
# 2119 of 2477 flows checked.
# 2120 of 2477 flows checked.
# 2121 of 2477 flows checked.
# 2122 of 2477 flows checked.
# 2123 of 2477 flows checked.
# 2124 of 2477 flows checked.
# 2125 of 2477 flows checked.
# 2126 of 2477 flows checked.
# 2127 of 2477 flows checked.
# 2128 of 2477 flows checked.
# 2129 of 2477 flows checked.
# 2130 of 2477 flows checked.
# 2131 of 2477 flows checked.
# 2132 of 2477 flows checked.
# 2133 of 2477 flows checked.
# 2134 of 2477 flows checked.
# 2135 of 2477 flows checked.
# 2136 of 2477 flows checked.
# 2137 of 2477 flows checked.
# 2138 of 2477 flows checked.
# 2139 of 2477 flows checked.
# 2140 of 2477 flows checked.
# 2141 of 2477 flows checked.
# 2142 of 2477 flows checked.
# 2143 of 2477 flows checked.
# 2144 of 2477 flows checked.
# 2145 of 2477 flows checked.
# 2146 of 2477 flows checked.
# 2147 of 2477 flows checked.
# 2148 of 2477 flows checked.
# 2149 of 2477 flows checked.
# 2150 of 2477 flows checked.
# 2151 of 2477 flows checked.
# 2152 of 2477 flows checked.
# 2153 of 2477 flows checked.
# 2154 of 2477 flows checked.
# 2155 of 2477 flows checked.
# 2156 of 2477 flows checked.
# 2157 of 2477 flows checked.
# 2158 of 2477 flows checked.
# 2159 of 2477 flows checked.
# 2160 of 2477 flows checked.
# 2161 of 2477 flows checked.
# 2162 of 2477 flows checked.
# 2163 of 2477 flows checked.
# 2164 of 2477 flows checked.
# 2165 of 2477 flows checked.
# 2166 of 2477 flows checked.
# 2167 of 2477 flows checked.
# 2168 of 2477 flows checked.
# 2169 of 2477 flows checked.
# 2170 of 2477 flows checked.
# 2171 of 2477 flows checked.
# 2172 of 2477 flows checked.
# 2173 of 2477 flows checked.
# 2174 of 2477 flows checked.
# 2175 of 2477 flows checked.
# 2176 of 2477 flows checked.
# 2177 of 2477 flows checked.
# 2178 of 2477 flows checked.
# 2179 of 2477 flows checked.
# 2180 of 2477 flows checked.
# 2181 of 2477 flows checked.
# 2182 of 2477 flows checked.
# 2183 of 2477 flows checked.
# 2184 of 2477 flows checked.
# 2185 of 2477 flows checked.
# 2186 of 2477 flows checked.
# 2187 of 2477 flows checked.
# 2188 of 2477 flows checked.
# 2189 of 2477 flows checked.
# 2190 of 2477 flows checked.
# 2191 of 2477 flows checked.
# 2192 of 2477 flows checked.
# 2193 of 2477 flows checked.
# 2194 of 2477 flows checked.
# 2195 of 2477 flows checked.
# 2196 of 2477 flows checked.
# 2197 of 2477 flows checked.
# 2198 of 2477 flows checked.
# 2199 of 2477 flows checked.
# 2200 of 2477 flows checked.
# 2201 of 2477 flows checked.
# 2202 of 2477 flows checked.
# 2203 of 2477 flows checked.
# 2204 of 2477 flows checked.
# 2205 of 2477 flows checked.
# 2206 of 2477 flows checked.
# 2207 of 2477 flows checked.
# 2208 of 2477 flows checked.
# 2209 of 2477 flows checked.
# 2210 of 2477 flows checked.
# 2211 of 2477 flows checked.
# 2212 of 2477 flows checked.
# 2213 of 2477 flows checked.
# 2214 of 2477 flows checked.
# 2215 of 2477 flows checked.
# 2216 of 2477 flows checked.
# 2217 of 2477 flows checked.
# 2218 of 2477 flows checked.
# 2219 of 2477 flows checked.
# 2220 of 2477 flows checked.
# 2221 of 2477 flows checked.
# 2222 of 2477 flows checked.
# 2223 of 2477 flows checked.
# 2224 of 2477 flows checked.
# 2225 of 2477 flows checked.
# 2226 of 2477 flows checked.
# 2227 of 2477 flows checked.
# 2228 of 2477 flows checked.
# 2229 of 2477 flows checked.
# 2230 of 2477 flows checked.
# 2231 of 2477 flows checked.
# 2232 of 2477 flows checked.
# 2233 of 2477 flows checked.
# 2234 of 2477 flows checked.
# 2235 of 2477 flows checked.
# 2236 of 2477 flows checked.
# 2237 of 2477 flows checked.
# 2238 of 2477 flows checked.
# 2239 of 2477 flows checked.
# 2240 of 2477 flows checked.
# 2241 of 2477 flows checked.
# 2242 of 2477 flows checked.
# 2243 of 2477 flows checked.
# 2244 of 2477 flows checked.
# 2245 of 2477 flows checked.
# 2246 of 2477 flows checked.
# 2247 of 2477 flows checked.
# 2248 of 2477 flows checked.
# 2249 of 2477 flows checked.
# 2250 of 2477 flows checked.
# 2251 of 2477 flows checked.
# 2252 of 2477 flows checked.
# 2253 of 2477 flows checked.
# 2254 of 2477 flows checked.
# 2255 of 2477 flows checked.
# 2256 of 2477 flows checked.
# 2257 of 2477 flows checked.
# 2258 of 2477 flows checked.
# 2259 of 2477 flows checked.
# 2260 of 2477 flows checked.
# 2261 of 2477 flows checked.
# 2262 of 2477 flows checked.
# 2263 of 2477 flows checked.
# 2264 of 2477 flows checked.
# 2265 of 2477 flows checked.
# 2266 of 2477 flows checked.
# 2267 of 2477 flows checked.
# 2268 of 2477 flows checked.
# 2269 of 2477 flows checked.
# 2270 of 2477 flows checked.
# 2271 of 2477 flows checked.
# 2272 of 2477 flows checked.
# 2273 of 2477 flows checked.
# 2274 of 2477 flows checked.
# 2275 of 2477 flows checked.
# 2276 of 2477 flows checked.
# 2277 of 2477 flows checked.
# 2278 of 2477 flows checked.
# 2279 of 2477 flows checked.
# 2280 of 2477 flows checked.
# 2281 of 2477 flows checked.
# 2282 of 2477 flows checked.
# 2283 of 2477 flows checked.
# 2284 of 2477 flows checked.
# 2285 of 2477 flows checked.
# 2286 of 2477 flows checked.
# 2287 of 2477 flows checked.
# 2288 of 2477 flows checked.
# 2289 of 2477 flows checked.
# 2290 of 2477 flows checked.
# 2291 of 2477 flows checked.
# 2292 of 2477 flows checked.
# 2293 of 2477 flows checked.
# 2294 of 2477 flows checked.
# 2295 of 2477 flows checked.
# 2296 of 2477 flows checked.
# 2297 of 2477 flows checked.
# 2298 of 2477 flows checked.
# 2299 of 2477 flows checked.
# 2300 of 2477 flows checked.
# 2301 of 2477 flows checked.
# 2302 of 2477 flows checked.
# 2303 of 2477 flows checked.
# 2304 of 2477 flows checked.
# 2305 of 2477 flows checked.
# 2306 of 2477 flows checked.
# 2307 of 2477 flows checked.
# 2308 of 2477 flows checked.
# 2309 of 2477 flows checked.
# 2310 of 2477 flows checked.
# 2311 of 2477 flows checked.
# 2312 of 2477 flows checked.
# 2313 of 2477 flows checked.
# 2314 of 2477 flows checked.
# 2315 of 2477 flows checked.
# 2316 of 2477 flows checked.
# 2317 of 2477 flows checked.
# 2318 of 2477 flows checked.
# 2319 of 2477 flows checked.
# 2320 of 2477 flows checked.
# 2321 of 2477 flows checked.
# 2322 of 2477 flows checked.
# 2323 of 2477 flows checked.
# 2324 of 2477 flows checked.
# 2325 of 2477 flows checked.
# 2326 of 2477 flows checked.
# 2327 of 2477 flows checked.
# 2328 of 2477 flows checked.
# 2329 of 2477 flows checked.
# 2330 of 2477 flows checked.
# 2331 of 2477 flows checked.
# 2332 of 2477 flows checked.
# 2333 of 2477 flows checked.
# 2334 of 2477 flows checked.
# 2335 of 2477 flows checked.
# 2336 of 2477 flows checked.
# 2337 of 2477 flows checked.
# 2338 of 2477 flows checked.
# 2339 of 2477 flows checked.
# 2340 of 2477 flows checked.
# 2341 of 2477 flows checked.
# 2342 of 2477 flows checked.
# 2343 of 2477 flows checked.
# 2344 of 2477 flows checked.
# 2345 of 2477 flows checked.
# 2346 of 2477 flows checked.
# 2347 of 2477 flows checked.
# 2348 of 2477 flows checked.
# 2349 of 2477 flows checked.
# 2350 of 2477 flows checked.
# 2351 of 2477 flows checked.
# 2352 of 2477 flows checked.
# 2353 of 2477 flows checked.
# 2354 of 2477 flows checked.
# 2355 of 2477 flows checked.
# 2356 of 2477 flows checked.
# 2357 of 2477 flows checked.
# 2358 of 2477 flows checked.
# 2359 of 2477 flows checked.
# 2360 of 2477 flows checked.
# 2361 of 2477 flows checked.
# 2362 of 2477 flows checked.
# 2363 of 2477 flows checked.
# 2364 of 2477 flows checked.
# 2365 of 2477 flows checked.
# 2366 of 2477 flows checked.
# 2367 of 2477 flows checked.
# 2368 of 2477 flows checked.
# 2369 of 2477 flows checked.
# 2370 of 2477 flows checked.
# 2371 of 2477 flows checked.
# 2372 of 2477 flows checked.
# 2373 of 2477 flows checked.
# 2374 of 2477 flows checked.
# 2375 of 2477 flows checked.
# 2376 of 2477 flows checked.
# 2377 of 2477 flows checked.
# 2378 of 2477 flows checked.
# 2379 of 2477 flows checked.
# 2380 of 2477 flows checked.
# 2381 of 2477 flows checked.
# 2382 of 2477 flows checked.
# 2383 of 2477 flows checked.
# 2384 of 2477 flows checked.
# 2385 of 2477 flows checked.
# 2386 of 2477 flows checked.
# 2387 of 2477 flows checked.
# 2388 of 2477 flows checked.
# 2389 of 2477 flows checked.
# 2390 of 2477 flows checked.
# 2391 of 2477 flows checked.
# 2392 of 2477 flows checked.
# 2393 of 2477 flows checked.
# 2394 of 2477 flows checked.
# 2395 of 2477 flows checked.
# 2396 of 2477 flows checked.
# 2397 of 2477 flows checked.
# 2398 of 2477 flows checked.
# 2399 of 2477 flows checked.
# 2400 of 2477 flows checked.
# 2401 of 2477 flows checked.
# 2402 of 2477 flows checked.
# 2403 of 2477 flows checked.
# 2404 of 2477 flows checked.
# 2405 of 2477 flows checked.
# 2406 of 2477 flows checked.
# 2407 of 2477 flows checked.
# 2408 of 2477 flows checked.
# 2409 of 2477 flows checked.
# 2410 of 2477 flows checked.
# 2411 of 2477 flows checked.
# 2412 of 2477 flows checked.
# 2413 of 2477 flows checked.
# 2414 of 2477 flows checked.
# 2415 of 2477 flows checked.
# 2416 of 2477 flows checked.
# 2417 of 2477 flows checked.
# 2418 of 2477 flows checked.
# 2419 of 2477 flows checked.
# 2420 of 2477 flows checked.
# 2421 of 2477 flows checked.
# 2422 of 2477 flows checked.
# 2423 of 2477 flows checked.
# 2424 of 2477 flows checked.
# 2425 of 2477 flows checked.
# 2426 of 2477 flows checked.
# 2427 of 2477 flows checked.
# 2428 of 2477 flows checked.
# 2429 of 2477 flows checked.
# 2430 of 2477 flows checked.
# 2431 of 2477 flows checked.
# 2432 of 2477 flows checked.
# 2433 of 2477 flows checked.
# 2434 of 2477 flows checked.
# 2435 of 2477 flows checked.
# 2436 of 2477 flows checked.
# 2437 of 2477 flows checked.
# 2438 of 2477 flows checked.
# 2439 of 2477 flows checked.
# 2440 of 2477 flows checked.
# 2441 of 2477 flows checked.
# 2442 of 2477 flows checked.
# 2443 of 2477 flows checked.
# 2444 of 2477 flows checked.
# 2445 of 2477 flows checked.
# 2446 of 2477 flows checked.
# 2447 of 2477 flows checked.
# 2448 of 2477 flows checked.
# 2449 of 2477 flows checked.
# 2450 of 2477 flows checked.
# 2451 of 2477 flows checked.
# 2452 of 2477 flows checked.
# 2453 of 2477 flows checked.
# 2454 of 2477 flows checked.
# 2455 of 2477 flows checked.
# 2456 of 2477 flows checked.
# 2457 of 2477 flows checked.
# 2458 of 2477 flows checked.
# 2459 of 2477 flows checked.
# 2460 of 2477 flows checked.
# 2461 of 2477 flows checked.
# 2462 of 2477 flows checked.
# 2463 of 2477 flows checked.
# 2464 of 2477 flows checked.
# 2465 of 2477 flows checked.
# 2466 of 2477 flows checked.
# 2467 of 2477 flows checked.
# 2468 of 2477 flows checked.
# 2469 of 2477 flows checked.
# 2470 of 2477 flows checked.
# 2471 of 2477 flows checked.
# 2472 of 2477 flows checked.
# 2473 of 2477 flows checked.
# 2474 of 2477 flows checked.
# 2475 of 2477 flows checked.
# 2476 of 2477 flows checked.
# 2477 of 2477 flows checked.

# %%
df_recipe_mapped = pd.concat(
    (
        df_recipe.set_index(["new flow name", "flow categories"]),
        flow_mapping.set_index(["new flow name", "flow categories"])
    ),
    axis=1
).reset_index()

df_recipe_mapped[["method", "unit", "new flow name", "flow categories", "mapped key", "CF"]].to_csv("../data/cfs_old_recipe_methods_mapped_w_keys.csv", index=False)

# %% [markdown]
# Add the methods to brightway:

# %%
recipe_cfs = pd.read_csv("../data/cfs_old_recipe_methods_mapped_w_keys.csv").dropna(subset="mapped key")
methods2add = list(recipe_cfs["method"].unique())

for m in methods2add:
    sel = recipe_cfs[recipe_cfs["method"] == m].copy()
    new_key = tuple(list(m.split(", ")))
    unit = sel["unit"].iloc[0]
    keys = list(sel["mapped key"])
    cfs = list(sel["CF"])
    new_cfs = [[eval(k), cf] for k, cf in zip(keys, cfs)]
    new_method = bd.Method(new_key)
    new_method.validate(new_cfs)
    new_method.register(unit=unit)
    new_method.write(new_cfs)

    print("Added method {}".format(str(new_method)))
# Out:
# Added method Brightway2 Method: ReCiPe Endpoint (E,A) w/o LT: ecosystem quality w/o LT: freshwater ecotoxicity w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (E,A) w/o LT: ecosystem quality w/o LT: freshwater eutrophication w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (E,A) w/o LT: ecosystem quality w/o LT: urban land occupation w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (E,A) w/o LT: ecosystem quality w/o LT: climate change: ecosystems w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (E,A) w/o LT: ecosystem quality w/o LT: terrestrial ecotoxicity w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (E,A) w/o LT: ecosystem quality w/o LT: agricultural land occupation w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (E,A) w/o LT: ecosystem quality w/o LT: marine ecotoxicity w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (E,A) w/o LT: ecosystem quality w/o LT: natural land transformation w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (E,A) w/o LT: ecosystem quality w/o LT: terrestrial acidification w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (E,A) w/o LT: human health w/o LT: ionising radiation w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (E,A) w/o LT: human health w/o LT: ozone depletion w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (E,A) w/o LT: human health w/o LT: human toxicity w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (E,A) w/o LT: human health w/o LT: particulate matter formation w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (E,A) w/o LT: human health w/o LT: climate change: human health w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (E,A) w/o LT: human health w/o LT: photochemical oxidant formation w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (E,A) w/o LT: resources w/o LT: metal depletion w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (E,A) w/o LT: resources w/o LT: fossil depletion w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (E,A) w/o LT: total w/o LT: total w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (E,A) w/o LT: resources w/o LT: total w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (E,A) w/o LT: human health w/o LT: total w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (E,A) w/o LT: ecosystem quality w/o LT: total w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (E,A): ecosystem quality: terrestrial ecotoxicity
# Added method Brightway2 Method: ReCiPe Endpoint (E,A): ecosystem quality: natural land transformation
# Added method Brightway2 Method: ReCiPe Endpoint (E,A): ecosystem quality: urban land occupation
# Added method Brightway2 Method: ReCiPe Endpoint (E,A): ecosystem quality: agricultural land occupation
# Added method Brightway2 Method: ReCiPe Endpoint (E,A): ecosystem quality: climate change: ecosystems
# Added method Brightway2 Method: ReCiPe Endpoint (E,A): ecosystem quality: freshwater eutrophication
# Added method Brightway2 Method: ReCiPe Endpoint (E,A): ecosystem quality: terrestrial acidification
# Added method Brightway2 Method: ReCiPe Endpoint (E,A): ecosystem quality: freshwater ecotoxicity
# Added method Brightway2 Method: ReCiPe Endpoint (E,A): ecosystem quality: marine ecotoxicity
# Added method Brightway2 Method: ReCiPe Endpoint (E,A): human health: human toxicity
# Added method Brightway2 Method: ReCiPe Endpoint (E,A): human health: ionising radiation
# Added method Brightway2 Method: ReCiPe Endpoint (E,A): human health: particulate matter formation
# Added method Brightway2 Method: ReCiPe Endpoint (E,A): human health: climate change: human health
# Added method Brightway2 Method: ReCiPe Endpoint (E,A): human health: photochemical oxidant formation
# Added method Brightway2 Method: ReCiPe Endpoint (E,A): human health: ozone depletion
# Added method Brightway2 Method: ReCiPe Endpoint (E,A): resources: fossil depletion
# Added method Brightway2 Method: ReCiPe Endpoint (E,A): resources: metal depletion
# Added method Brightway2 Method: ReCiPe Endpoint (E,A): human health: total
# Added method Brightway2 Method: ReCiPe Endpoint (E,A): ecosystem quality: total
# Added method Brightway2 Method: ReCiPe Endpoint (E,A): resources: total
# Added method Brightway2 Method: ReCiPe Endpoint (E,A): total: total
# Added method Brightway2 Method: ReCiPe Endpoint (H,A) w/o LT: ecosystem quality w/o LT: freshwater ecotoxicity w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (H,A) w/o LT: ecosystem quality w/o LT: freshwater eutrophication w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (H,A) w/o LT: ecosystem quality w/o LT: urban land occupation w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (H,A) w/o LT: ecosystem quality w/o LT: climate change: ecosystems w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (H,A) w/o LT: ecosystem quality w/o LT: terrestrial ecotoxicity w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (H,A) w/o LT: ecosystem quality w/o LT: agricultural land occupation w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (H,A) w/o LT: ecosystem quality w/o LT: marine ecotoxicity w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (H,A) w/o LT: ecosystem quality w/o LT: natural land transformation w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (H,A) w/o LT: ecosystem quality w/o LT: terrestrial acidification w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (H,A) w/o LT: human health w/o LT: ionising radiation w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (H,A) w/o LT: human health w/o LT: ozone depletion w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (H,A) w/o LT: human health w/o LT: human toxicity w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (H,A) w/o LT: human health w/o LT: particulate matter formation w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (H,A) w/o LT: human health w/o LT: climate change: human health w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (H,A) w/o LT: human health w/o LT: photochemical oxidant formation w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (H,A) w/o LT: resources w/o LT: metal depletion w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (H,A) w/o LT: resources w/o LT: fossil depletion w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (H,A) w/o LT: human health w/o LT: total w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (H,A) w/o LT: resources w/o LT: total w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (H,A) w/o LT: ecosystem quality w/o LT: total w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (H,A) w/o LT: total w/o LT: total w/o LT
# Added method Brightway2 Method: ReCiPe Endpoint (H,A): ecosystem quality: terrestrial ecotoxicity
# Added method Brightway2 Method: ReCiPe Endpoint (H,A): ecosystem quality: natural land transformation
# Added method Brightway2 Method: ReCiPe Endpoint (H,A): ecosystem quality: urban land occupation
# Added method Brightway2 Method: ReCiPe Endpoint (H,A): ecosystem quality: agricultural land occupation
# Added method Brightway2 Method: ReCiPe Endpoint (H,A): ecosystem quality: climate change: ecosystems
# Added method Brightway2 Method: ReCiPe Endpoint (H,A): ecosystem quality: freshwater eutrophication
# Added method Brightway2 Method: ReCiPe Endpoint (H,A): ecosystem quality: terrestrial acidification
# Added method Brightway2 Method: ReCiPe Endpoint (H,A): ecosystem quality: freshwater ecotoxicity
# Added method Brightway2 Method: ReCiPe Endpoint (H,A): ecosystem quality: marine ecotoxicity
# Added method Brightway2 Method: ReCiPe Endpoint (H,A): human health: human toxicity
# Added method Brightway2 Method: ReCiPe Endpoint (H,A): human health: ionising radiation
# Added method Brightway2 Method: ReCiPe Endpoint (H,A): human health: particulate matter formation
# Added method Brightway2 Method: ReCiPe Endpoint (H,A): human health: climate change: human health
# Added method Brightway2 Method: ReCiPe Endpoint (H,A): human health: photochemical oxidant formation
# Added method Brightway2 Method: ReCiPe Endpoint (H,A): human health: ozone depletion
# Added method Brightway2 Method: ReCiPe Endpoint (H,A): resources: fossil depletion
# Added method Brightway2 Method: ReCiPe Endpoint (H,A): resources: metal depletion
# Added method Brightway2 Method: ReCiPe Endpoint (H,A): total: total
# Added method Brightway2 Method: ReCiPe Endpoint (H,A): ecosystem quality: total
# Added method Brightway2 Method: ReCiPe Endpoint (H,A): resources: total
# Added method Brightway2 Method: ReCiPe Endpoint (H,A): human health: total
# Added method Brightway2 Method: ReCiPe Endpoint (I,A): ecosystem quality: terrestrial ecotoxicity
# Added method Brightway2 Method: ReCiPe Endpoint (I,A): ecosystem quality: natural land transformation
# Added method Brightway2 Method: ReCiPe Endpoint (I,A): ecosystem quality: urban land occupation
# Added method Brightway2 Method: ReCiPe Endpoint (I,A): ecosystem quality: agricultural land occupation
# Added method Brightway2 Method: ReCiPe Endpoint (I,A): ecosystem quality: climate change: ecosystems
# Added method Brightway2 Method: ReCiPe Endpoint (I,A): ecosystem quality: freshwater eutrophication
# Added method Brightway2 Method: ReCiPe Endpoint (I,A): ecosystem quality: terrestrial acidification
# Added method Brightway2 Method: ReCiPe Endpoint (I,A): ecosystem quality: freshwater ecotoxicity
# Added method Brightway2 Method: ReCiPe Endpoint (I,A): ecosystem quality: marine ecotoxicity
# Added method Brightway2 Method: ReCiPe Endpoint (I,A): human health: human toxicity
# Added method Brightway2 Method: ReCiPe Endpoint (I,A): human health: ionising radiation
# Added method Brightway2 Method: ReCiPe Endpoint (I,A): human health: particulate matter formation
# Added method Brightway2 Method: ReCiPe Endpoint (I,A): human health: climate change: human health
# Added method Brightway2 Method: ReCiPe Endpoint (I,A): human health: photochemical oxidant formation
# Added method Brightway2 Method: ReCiPe Endpoint (I,A): human health: ozone depletion
# Added method Brightway2 Method: ReCiPe Endpoint (I,A): resources: fossil depletion
# Added method Brightway2 Method: ReCiPe Endpoint (I,A): resources: metal depletion
# Added method Brightway2 Method: ReCiPe Endpoint (I,A): resources: total
# Added method Brightway2 Method: ReCiPe Endpoint (I,A): total: total
# Added method Brightway2 Method: ReCiPe Endpoint (I,A): ecosystem quality: total
# Added method Brightway2 Method: ReCiPe Endpoint (I,A): human health: total
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13 no LT: water depletion: WDP
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13 no LT: fossil depletion: FDP
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13 no LT: marine eutrophication: MEP
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13 no LT: climate change: GWP500
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13 no LT: agricultural land occupation: ALOP
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13 no LT: human toxicity: HTPinf
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13 no LT: marine ecotoxicity: METPinf
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13 no LT: metal depletion: MDP
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13 no LT: terrestrial ecotoxicity: TETPinf
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13 no LT: particulate matter formation: PMFP
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13 no LT: ionising radiation: IRP_HE
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13 no LT: ozone depletion: ODPinf
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13 no LT: natural land transformation: NLTP
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13 no LT: terrestrial acidification: TAP500
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13 no LT: freshwater ecotoxicity: FETPinf
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13 no LT: urban land occupation: ULOP
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13 no LT: photochemical oxidant formation: POFP
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13 no LT: freshwater eutrophication: FEP
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13: water depletion: WDP
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13: fossil depletion: FDP
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13: marine eutrophication: MEP
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13: climate change: GWP500
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13: agricultural land occupation: ALOP
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13: human toxicity: HTPinf
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13: marine ecotoxicity: METPinf
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13: metal depletion: MDP
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13: terrestrial ecotoxicity: TETPinf
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13: particulate matter formation: PMFP
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13: ionising radiation: IRP_HE
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13: ozone depletion: ODPinf
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13: natural land transformation: NLTP
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13: terrestrial acidification: TAP500
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13: freshwater ecotoxicity: FETPinf
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13: urban land occupation: ULOP
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13: photochemical oxidant formation: POFP
# Added method Brightway2 Method: ReCiPe Midpoint (E) V1.13: freshwater eutrophication: FEP
# Added method Brightway2 Method: ReCiPe Midpoint (E) w/o LT: freshwater ecotoxicity w/o LT: FETPinf w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (E) w/o LT: ionising radiation w/o LT: IRP_HE w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (E) w/o LT: climate change w/o LT: GWP500 w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (E) w/o LT: fossil depletion w/o LT: FDP w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (E) w/o LT: water depletion w/o LT: WDP w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (E) w/o LT: ozone depletion w/o LT: ODPinf w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (E) w/o LT: marine eutrophication w/o LT: MEP w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (E) w/o LT: freshwater eutrophication w/o LT: FEP w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (E) w/o LT: terrestrial ecotoxicity w/o LT: TETPinf w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (E) w/o LT: particulate matter formation w/o LT: PMFP w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (E) w/o LT: urban land occupation w/o LT: ULOP w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (E) w/o LT: terrestrial acidification w/o LT: TAP500 w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (E) w/o LT: human toxicity w/o LT: HTPinf w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (E) w/o LT: agricultural land occupation w/o LT: ALOP w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (E) w/o LT: marine ecotoxicity w/o LT: METPinf w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (E) w/o LT: photochemical oxidant formation w/o LT: POFP w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (E) w/o LT: metal depletion w/o LT: MDP w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (E) w/o LT: natural land transformation w/o LT: NLTP w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (E): terrestrial ecotoxicity: TETPinf
# Added method Brightway2 Method: ReCiPe Midpoint (E): natural land transformation: NLTP
# Added method Brightway2 Method: ReCiPe Midpoint (E): photochemical oxidant formation: POFP
# Added method Brightway2 Method: ReCiPe Midpoint (E): human toxicity: HTPinf
# Added method Brightway2 Method: ReCiPe Midpoint (E): marine eutrophication: MEP
# Added method Brightway2 Method: ReCiPe Midpoint (E): climate change: GWP500
# Added method Brightway2 Method: ReCiPe Midpoint (E): particulate matter formation: PMFP
# Added method Brightway2 Method: ReCiPe Midpoint (E): agricultural land occupation: ALOP
# Added method Brightway2 Method: ReCiPe Midpoint (E): freshwater eutrophication: FEP
# Added method Brightway2 Method: ReCiPe Midpoint (E): metal depletion: MDP
# Added method Brightway2 Method: ReCiPe Midpoint (E): terrestrial acidification: TAP500
# Added method Brightway2 Method: ReCiPe Midpoint (E): water depletion: WDP
# Added method Brightway2 Method: ReCiPe Midpoint (E): urban land occupation: ULOP
# Added method Brightway2 Method: ReCiPe Midpoint (E): ionising radiation: IRP_HE
# Added method Brightway2 Method: ReCiPe Midpoint (E): fossil depletion: FDP
# Added method Brightway2 Method: ReCiPe Midpoint (E): freshwater ecotoxicity: FETPinf
# Added method Brightway2 Method: ReCiPe Midpoint (E): marine ecotoxicity: METPinf
# Added method Brightway2 Method: ReCiPe Midpoint (E): ozone depletion: ODPinf
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13 no LT: agricultural land occupation: ALOP
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13 no LT: ozone depletion: ODPinf
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13 no LT: climate change: GWP100
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13 no LT: terrestrial acidification: TAP100
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13 no LT: photochemical oxidant formation: POFP
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13 no LT: metal depletion: MDP
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13 no LT: water depletion: WDP
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13 no LT: freshwater ecotoxicity: FETPinf
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13 no LT: human toxicity: HTPinf
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13 no LT: urban land occupation: ULOP
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13 no LT: particulate matter formation: PMFP
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13 no LT: freshwater eutrophication: FEP
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13 no LT: natural land transformation: NLTP
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13 no LT: marine eutrophication: MEP
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13 no LT: terrestrial ecotoxicity: TETPinf
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13 no LT: fossil depletion: FDP
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13 no LT: ionising radiation: IRP_HE
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13 no LT: marine ecotoxicity: METPinf
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13: agricultural land occupation: ALOP
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13: ozone depletion: ODPinf
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13: climate change: GWP100
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13: terrestrial acidification: TAP100
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13: photochemical oxidant formation: POFP
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13: metal depletion: MDP
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13: water depletion: WDP
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13: freshwater ecotoxicity: FETPinf
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13: human toxicity: HTPinf
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13: urban land occupation: ULOP
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13: particulate matter formation: PMFP
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13: freshwater eutrophication: FEP
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13: natural land transformation: NLTP
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13: marine eutrophication: MEP
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13: terrestrial ecotoxicity: TETPinf
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13: fossil depletion: FDP
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13: ionising radiation: IRP_HE
# Added method Brightway2 Method: ReCiPe Midpoint (H) V1.13: marine ecotoxicity: METPinf
# Added method Brightway2 Method: ReCiPe Midpoint (H) w/o LT: freshwater ecotoxicity w/o LT: FETPinf w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (H) w/o LT: ionising radiation w/o LT: IRP_HE w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (H) w/o LT: climate change w/o LT: GWP100 w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (H) w/o LT: fossil depletion w/o LT: FDP w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (H) w/o LT: water depletion w/o LT: WDP w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (H) w/o LT: ozone depletion w/o LT: ODPinf w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (H) w/o LT: marine eutrophication w/o LT: MEP w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (H) w/o LT: freshwater eutrophication w/o LT: FEP w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (H) w/o LT: terrestrial ecotoxicity w/o LT: TETPinf w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (H) w/o LT: particulate matter formation w/o LT: PMFP w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (H) w/o LT: urban land occupation w/o LT: ULOP w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (H) w/o LT: terrestrial acidification w/o LT: TAP100 w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (H) w/o LT: human toxicity w/o LT: HTPinf w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (H) w/o LT: agricultural land occupation w/o LT: ALOP w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (H) w/o LT: marine ecotoxicity w/o LT: METPinf w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (H) w/o LT: photochemical oxidant formation w/o LT: POFP w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (H) w/o LT: metal depletion w/o LT: MDP w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (H) w/o LT: natural land transformation w/o LT: NLTP w/o LT
# Added method Brightway2 Method: ReCiPe Midpoint (H): terrestrial ecotoxicity: TETPinf
# Added method Brightway2 Method: ReCiPe Midpoint (H): natural land transformation: NLTP
# Added method Brightway2 Method: ReCiPe Midpoint (H): photochemical oxidant formation: POFP
# Added method Brightway2 Method: ReCiPe Midpoint (H): human toxicity: HTPinf
# Added method Brightway2 Method: ReCiPe Midpoint (H): marine eutrophication: MEP
# Added method Brightway2 Method: ReCiPe Midpoint (H): climate change: GWP100
# Added method Brightway2 Method: ReCiPe Midpoint (H): particulate matter formation: PMFP
# Added method Brightway2 Method: ReCiPe Midpoint (H): agricultural land occupation: ALOP
# Added method Brightway2 Method: ReCiPe Midpoint (H): freshwater eutrophication: FEP
# Added method Brightway2 Method: ReCiPe Midpoint (H): metal depletion: MDP
# Added method Brightway2 Method: ReCiPe Midpoint (H): terrestrial acidification: TAP100
# Added method Brightway2 Method: ReCiPe Midpoint (H): water depletion: WDP
# Added method Brightway2 Method: ReCiPe Midpoint (H): urban land occupation: ULOP
# Added method Brightway2 Method: ReCiPe Midpoint (H): ionising radiation: IRP_HE
# Added method Brightway2 Method: ReCiPe Midpoint (H): fossil depletion: FDP
# Added method Brightway2 Method: ReCiPe Midpoint (H): freshwater ecotoxicity: FETPinf
# Added method Brightway2 Method: ReCiPe Midpoint (H): marine ecotoxicity: METPinf
# Added method Brightway2 Method: ReCiPe Midpoint (H): ozone depletion: ODPinf
# Added method Brightway2 Method: ReCiPe Midpoint (I) V1.13: climate change: GWP20
# Added method Brightway2 Method: ReCiPe Midpoint (I) V1.13: ionising radiation: IRP_I
# Added method Brightway2 Method: ReCiPe Midpoint (I) V1.13: marine eutrophication: MEP
# Added method Brightway2 Method: ReCiPe Midpoint (I) V1.13: freshwater eutrophication: FEP
# Added method Brightway2 Method: ReCiPe Midpoint (I) V1.13: metal depletion: MDP
# Added method Brightway2 Method: ReCiPe Midpoint (I) V1.13: photochemical oxidant formation: POFP
# Added method Brightway2 Method: ReCiPe Midpoint (I) V1.13: particulate matter formation: PMFP
# Added method Brightway2 Method: ReCiPe Midpoint (I) V1.13: water depletion: WDP
# Added method Brightway2 Method: ReCiPe Midpoint (I) V1.13: freshwater ecotoxicity: FETP100
# Added method Brightway2 Method: ReCiPe Midpoint (I) V1.13: human toxicity: HTP100
# Added method Brightway2 Method: ReCiPe Midpoint (I) V1.13: agricultural land occupation: ALOP
# Added method Brightway2 Method: ReCiPe Midpoint (I) V1.13: marine ecotoxicity: METP100
# Added method Brightway2 Method: ReCiPe Midpoint (I) V1.13: terrestrial ecotoxicity: TETP100
# Added method Brightway2 Method: ReCiPe Midpoint (I) V1.13: terrestrial acidification: TAP20
# Added method Brightway2 Method: ReCiPe Midpoint (I) V1.13: fossil depletion: FDP
# Added method Brightway2 Method: ReCiPe Midpoint (I) V1.13: natural land transformation: NLTP
# Added method Brightway2 Method: ReCiPe Midpoint (I) V1.13: ozone depletion: ODPinf
# Added method Brightway2 Method: ReCiPe Midpoint (I) V1.13: urban land occupation: ULOP
# Added method Brightway2 Method: ReCiPe Midpoint (I): terrestrial ecotoxicity: TETP100
# Added method Brightway2 Method: ReCiPe Midpoint (I): natural land transformation: NLTP
# Added method Brightway2 Method: ReCiPe Midpoint (I): photochemical oxidant formation: POFP
# Added method Brightway2 Method: ReCiPe Midpoint (I): human toxicity: HTP100
# Added method Brightway2 Method: ReCiPe Midpoint (I): marine eutrophication: MEP
# Added method Brightway2 Method: ReCiPe Midpoint (I): climate change: GWP20
# Added method Brightway2 Method: ReCiPe Midpoint (I): particulate matter formation: PMFP
# Added method Brightway2 Method: ReCiPe Midpoint (I): agricultural land occupation: ALOP
# Added method Brightway2 Method: ReCiPe Midpoint (I): freshwater eutrophication: FEP
# Added method Brightway2 Method: ReCiPe Midpoint (I): metal depletion: MDP
# Added method Brightway2 Method: ReCiPe Midpoint (I): terrestrial acidification: TAP20
# Added method Brightway2 Method: ReCiPe Midpoint (I): water depletion: WDP
# Added method Brightway2 Method: ReCiPe Midpoint (I): urban land occupation: ULOP
# Added method Brightway2 Method: ReCiPe Midpoint (I): ionising radiation: IRP_I
# Added method Brightway2 Method: ReCiPe Midpoint (I): fossil depletion: FDP
# Added method Brightway2 Method: ReCiPe Midpoint (I): freshwater ecotoxicity: FETP100
# Added method Brightway2 Method: ReCiPe Midpoint (I): marine ecotoxicity: METP100
# Added method Brightway2 Method: ReCiPe Midpoint (I): ozone depletion: ODPinf
